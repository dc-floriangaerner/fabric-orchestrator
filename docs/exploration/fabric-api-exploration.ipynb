# %% [markdown]
# # Microsoft Fabric API - Complete API Exploration
#
# This notebook systematically explores the **ENTIRE** `microsoft-fabric-api` library structure to document all available methods across all modules.
#
# **What this notebook documents:**
# - All top-level modules in `fabric_client` (core, admin, workload-specific modules, etc.)
# - All sub-modules within each top-level module
# - All methods with signatures and docstrings
# - All properties and attributes
# - Complete API surface area
#
# **Output:** `fabric-api-complete-documentation.json` with comprehensive API documentation

# %% [markdown]
# ## Setup and Authentication

# %%
# %pip install microsoft-fabric-api azure-identity
# Out:
# Requirement already satisfied: microsoft-fabric-api in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (0.1.0b2)
# Requirement already satisfied: azure-identity in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (1.25.2)
# Requirement already satisfied: isodate<1.0.0,>=0.6.1 in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (from microsoft-fabric-api) (0.7.2)
# Requirement already satisfied: azure-core<2.0.0,>=1.24.0 in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (from microsoft-fabric-api) (1.38.1)
# Requirement already satisfied: requests>=2.21.0 in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (from azure-core<2.0.0,>=1.24.0->microsoft-fabric-api) (2.32.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (from azure-core<2.0.0,>=1.24.0->microsoft-fabric-api) (4.15.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (from azure-identity) (46.0.5)
# Requirement already satisfied: msal>=1.31.0 in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (3.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.31.0->azure-identity) (2.11.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->microsoft-fabric-api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->microsoft-fabric-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->microsoft-fabric-api) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\florian.gaerner\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->microsoft-fabric-api) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import inspect
import json
import os

from azure.identity import ClientSecretCredential
from microsoft_fabric_api import FabricClient

# %%
# Configure credentials
client_id = os.getenv("AZURE_CLIENT_ID", "your-client-id-here")
client_secret = os.getenv("AZURE_CLIENT_SECRET", "your-client-secret-here")
tenant_id = os.getenv("AZURE_TENANT_ID", "your-tenant-id-here")

credential = ClientSecretCredential(tenant_id=tenant_id, client_id=client_id, client_secret=client_secret)

fabric_client = FabricClient(token_credential=credential)
print("✓ Client initialized")
# Out:
# ✓ Client initialized

# %% [markdown]
# ## Complete API Structure Extraction

# %%
def get_method_details(obj, method_name):
    """Extract detailed information about a method."""
    method = getattr(obj, method_name)
    details = {
        "name": method_name,
        "signature": str(inspect.signature(method)) if callable(method) else None,
        "docstring": inspect.getdoc(method),
        "type": type(method).__name__,
    }
    return details


def explore_object(obj, path="", max_depth=5, current_depth=0):
    """Recursively explore an object's structure."""
    if current_depth >= max_depth:
        return {}

    structure = {"path": path, "type": type(obj).__name__, "attributes": {}, "methods": {}}

    for attr_name in dir(obj):
        if attr_name.startswith("_"):
            continue

        try:
            attr = getattr(obj, attr_name)
            new_path = f"{path}.{attr_name}" if path else attr_name

            if callable(attr):
                structure["methods"][attr_name] = get_method_details(obj, attr_name)
            else:
                # Non-callable attribute - might be a sub-module
                structure["attributes"][attr_name] = {"type": type(attr).__name__, "path": new_path}
        except Exception as e:
            structure["attributes"][attr_name] = {"error": str(e)}

    return structure

# %%
# Explore FabricClient top-level
print("Exploring FabricClient...")
print("=" * 80)

client_structure = explore_object(fabric_client, "fabric_client")

print("\nTop-level attributes:")
for attr_name, attr_info in client_structure["attributes"].items():
    print(f"  • {attr_name}: {attr_info['type']}")

print("\nTop-level methods:")
for method_name in client_structure["methods"].keys():
    print(f"  • {method_name}()")
# Out:
# Exploring FabricClient...
# ================================================================================
#
# Top-level attributes:
#   • admin: FabricAdminClient
#   • anomalydetector: FabricAnomalyDetectorClient
#   • apacheairflowjob: FabricApacheAirflowJobClient
#   • copyjob: FabricCopyJobClient
#   • core: FabricCoreClient
#   • cosmosdbdatabase: FabricCosmosDBDatabaseClient
#   • dashboard: FabricDashboardClient
#   • dataflow: FabricDataflowClient
#   • datamart: FabricDatamartClient
#   • datapipeline: FabricDataPipelineClient
#   • digitaltwinbuilder: FabricDigitalTwinBuilderClient
#   • digitaltwinbuilderflow: FabricDigitalTwinBuilderFlowClient
#   • environment: FabricEnvironmentClient
#   • eventhouse: FabricEventhouseClient
#   • eventstream: FabricEventstreamClient
#   • graphmodel: FabricGraphModelClient
#   • graphqlapi: FabricGraphQLApiClient
#   • graphqueryset: FabricGraphQuerySetClient
#   • kqldashboard: FabricKQLDashboardClient
#   • kqldatabase: FabricKQLDatabaseClient
#   • kqlqueryset: FabricKQLQuerysetClient
#   • lakehouse: FabricLakehouseClient
#   • map: FabricMapClient
#   • mirroredazuredatabrickscatalog: FabricMirroredAzureDatabricksCatalogClient
#   • mirroreddatabase: FabricMirroredDatabaseClient
#   • mirroredwarehouse: FabricMirroredWarehouseClient
#   • mlexperiment: FabricMLExperimentClient
#   • mlmodel: FabricMLModelClient
#   • mounteddatafactory: FabricMountedDataFactoryClient
#   • notebook: FabricNotebookClient
#   • ontology: FabricOntologyClient
#   • operationsagent: FabricOperationsAgentClient
#   • paginatedreport: FabricPaginatedReportClient
#   • reflex: FabricReflexClient
#   • report: FabricReportClient
#   • semanticmodel: FabricSemanticModelClient
#   • spark: FabricSparkClient
#   • sparkjobdefinition: FabricSparkJobDefinitionClient
#   • sqldatabase: FabricSQLDatabaseClient
#   • sqlendpoint: FabricSQLEndpointClient
#   • userdatafunction: FabricUserDataFunctionClient
#   • variablelibrary: FabricVariableLibraryClient
#   • warehouse: FabricWarehouseClient
#   • warehousesnapshot: FabricWarehouseSnapshotClient
#
# Top-level methods:

# %% [markdown]
# ## Discover All Top-Level Modules
#
# Explore all modules in fabric_client, not just core.

# %%
# Discover all top-level modules (not just core)
print("Discovering all top-level modules in fabric_client...")
print("=" * 80)

all_top_level_modules = {}

for attr_name in dir(fabric_client):
    if not attr_name.startswith("_"):
        try:
            attr = getattr(fabric_client, attr_name)
            if not callable(attr):
                all_top_level_modules[attr_name] = {
                    "object": attr,
                    "type": type(attr).__name__,
                    "path": f"fabric_client.{attr_name}",
                }
                print(f"  • {attr_name}: {type(attr).__name__}")
        except Exception as e:
            print(f"  ✗ {attr_name}: Error - {e!s}")

print(f"\nFound {len(all_top_level_modules)} top-level modules")
# Out:
# Discovering all top-level modules in fabric_client...
# ================================================================================
#   • admin: FabricAdminClient
#   • anomalydetector: FabricAnomalyDetectorClient
#   • apacheairflowjob: FabricApacheAirflowJobClient
#   • copyjob: FabricCopyJobClient
#   • core: FabricCoreClient
#   • cosmosdbdatabase: FabricCosmosDBDatabaseClient
#   • dashboard: FabricDashboardClient
#   • dataflow: FabricDataflowClient
#   • datamart: FabricDatamartClient
#   • datapipeline: FabricDataPipelineClient
#   • digitaltwinbuilder: FabricDigitalTwinBuilderClient
#   • digitaltwinbuilderflow: FabricDigitalTwinBuilderFlowClient
#   • environment: FabricEnvironmentClient
#   • eventhouse: FabricEventhouseClient
#   • eventstream: FabricEventstreamClient
#   • graphmodel: FabricGraphModelClient
#   • graphqlapi: FabricGraphQLApiClient
#   • graphqueryset: FabricGraphQuerySetClient
#   • kqldashboard: FabricKQLDashboardClient
#   • kqldatabase: FabricKQLDatabaseClient
#   • kqlqueryset: FabricKQLQuerysetClient
#   • lakehouse: FabricLakehouseClient
#   • map: FabricMapClient
#   • mirroredazuredatabrickscatalog: FabricMirroredAzureDatabricksCatalogClient
#   • mirroreddatabase: FabricMirroredDatabaseClient
#   • mirroredwarehouse: FabricMirroredWarehouseClient
#   • mlexperiment: FabricMLExperimentClient
#   • mlmodel: FabricMLModelClient
#   • mounteddatafactory: FabricMountedDataFactoryClient
#   • notebook: FabricNotebookClient
#   • ontology: FabricOntologyClient
#   • operationsagent: FabricOperationsAgentClient
#   • paginatedreport: FabricPaginatedReportClient
#   • reflex: FabricReflexClient
#   • report: FabricReportClient
#   • semanticmodel: FabricSemanticModelClient
#   • spark: FabricSparkClient
#   • sparkjobdefinition: FabricSparkJobDefinitionClient
#   • sqldatabase: FabricSQLDatabaseClient
#   • sqlendpoint: FabricSQLEndpointClient
#   • userdatafunction: FabricUserDataFunctionClient
#   • variablelibrary: FabricVariableLibraryClient
#   • warehouse: FabricWarehouseClient
#   • warehousesnapshot: FabricWarehouseSnapshotClient
#
# Found 44 top-level modules

# %%
# Explore sub-modules within each top-level module
all_modules_to_explore = {}

for top_name, top_info in all_top_level_modules.items():
    top_obj = top_info["object"]

    print(f"\nExploring {top_name}...")
    print("-" * 60)

    # Check for sub-modules
    for attr_name in dir(top_obj):
        if not attr_name.startswith("_"):
            try:
                attr = getattr(top_obj, attr_name)
                if not callable(attr):
                    full_path = f"{top_name}.{attr_name}"
                    all_modules_to_explore[full_path] = {
                        "object": attr,
                        "type": type(attr).__name__,
                        "path": f"fabric_client.{full_path}",
                    }
                    print(f"  • {full_path}: {type(attr).__name__}")
            except:
                pass

print(f"\n{'='*80}")
print(f"Total modules to explore in detail: {len(all_modules_to_explore)}")
# Out:
# Exploring admin...
# ------------------------------------------------------------
#   • admin.domains: DomainsOperations
#   • admin.external_data_shares_provider: ExternalDataSharesProviderOperations
#   • admin.items: ItemsOperations
#   • admin.labels: LabelsOperations
#   • admin.sharing_links: SharingLinksOperations
#   • admin.sharinglinks: SharingLinksOperations
#   • admin.tags: TagsOperations
#   • admin.tenants: TenantsOperations
#   • admin.users: UsersOperations
#   • admin.workspaces: WorkspacesOperations
#
# Exploring anomalydetector...
# ------------------------------------------------------------
#   • anomalydetector.items: ItemsOperations
#
# Exploring apacheairflowjob...
# ------------------------------------------------------------
#   • apacheairflowjob.files: FilesOperations
#   • apacheairflowjob.items: ItemsOperations
#   • apacheairflowjob.pool_management: PoolManagementOperations
#   • apacheairflowjob.workspace_settings: WorkspaceSettingsOperations
#
# Exploring copyjob...
# ------------------------------------------------------------
#   • copyjob.items: ItemsOperations
#
# Exploring core...
# ------------------------------------------------------------
#   • core.capacities: CapacitiesOperations
#   • core.connections: ConnectionsOperations
#   • core.deployment_pipelines: DeploymentPipelinesOperations
#   • core.deploymentpipelines: DeploymentPipelinesOperations
#   • core.domains: DomainsOperations
#   • core.external_data_shares_provider: ExternalDataSharesProviderOperations
#   • core.external_data_shares_recipient: ExternalDataSharesRecipientOperations
#   • core.folders: FoldersOperations
#   • core.gateways: GatewaysOperations
#   • core.git: GitOperations
#   • core.items: ItemsOperations
#   • core.job_scheduler: JobSchedulerOperations
#   • core.long_running_operations: LongRunningOperationsOperations
#   • core.managed_private_endpoints: ManagedPrivateEndpointsOperations
#   • core.one_lake_data_access_security: OneLakeDataAccessSecurityOperations
#   • core.one_lake_settings: OneLakeSettingsOperations
#   • core.one_lake_shortcuts: OneLakeShortcutsOperations
#   • core.onelakesettings: OneLakeSettingsOperations
#   • core.onelakeshortcuts: OneLakeShortcutsOperations
#   • core.tags: TagsOperations
#   • core.workspaces: WorkspacesOperations
#
# Exploring cosmosdbdatabase...
# ------------------------------------------------------------
#   • cosmosdbdatabase.items: ItemsOperations
#
# Exploring dashboard...
# ------------------------------------------------------------
#   • dashboard.items: ItemsOperations
#
# Exploring dataflow...
# ------------------------------------------------------------
#   • dataflow.background_jobs: BackgroundJobsOperations
#   • dataflow.items: ItemsOperations
#   • dataflow.query_execution: QueryExecutionOperations
#   • dataflow.queryexecution: QueryExecutionOperations
#
# Exploring datamart...
# ------------------------------------------------------------
#   • datamart.items: ItemsOperations
#
# Exploring datapipeline...
# ------------------------------------------------------------
#   • datapipeline.items: ItemsOperations
#
# Exploring digitaltwinbuilder...
# ------------------------------------------------------------
#   • digitaltwinbuilder.items: ItemsOperations
#
# Exploring digitaltwinbuilderflow...
# ------------------------------------------------------------
#   • digitaltwinbuilderflow.items: ItemsOperations
#
# Exploring environment...
# ------------------------------------------------------------
#   • environment.items: ItemsOperations
#   • environment.published: PublishedOperations
#   • environment.staging: StagingOperations
#
# Exploring eventhouse...
# ------------------------------------------------------------
#   • eventhouse.items: ItemsOperations
#
# Exploring eventstream...
# ------------------------------------------------------------
#   • eventstream.items: ItemsOperations
#   • eventstream.topology: TopologyOperations
#
# Exploring graphmodel...
# ------------------------------------------------------------
#   • graphmodel.background_jobs: BackgroundJobsOperations
#   • graphmodel.items: ItemsOperations
#
# Exploring graphqlapi...
# ------------------------------------------------------------
#   • graphqlapi.items: ItemsOperations
#
# Exploring graphqueryset...
# ------------------------------------------------------------
#   • graphqueryset.items: ItemsOperations
#
# Exploring kqldashboard...
# ------------------------------------------------------------
#   • kqldashboard.items: ItemsOperations
#
# Exploring kqldatabase...
# ------------------------------------------------------------
#   • kqldatabase.items: ItemsOperations
#
# Exploring kqlqueryset...
# ------------------------------------------------------------
#   • kqlqueryset.items: ItemsOperations
#
# Exploring lakehouse...
# ------------------------------------------------------------
#   • lakehouse.background_jobs: BackgroundJobsOperations
#   • lakehouse.items: ItemsOperations
#   • lakehouse.livy_sessions: LivySessionsOperations
#   • lakehouse.tables: TablesOperations
#
# Exploring map...
# ------------------------------------------------------------
#   • map.items: ItemsOperations
#
# Exploring mirroredazuredatabrickscatalog...
# ------------------------------------------------------------
#   • mirroredazuredatabrickscatalog.discovery: DiscoveryOperations
#   • mirroredazuredatabrickscatalog.items: ItemsOperations
#   • mirroredazuredatabrickscatalog.refresh: RefreshOperations
#
# Exploring mirroreddatabase...
# ------------------------------------------------------------
#   • mirroreddatabase.items: ItemsOperations
#   • mirroreddatabase.mirroring: MirroringOperations
#
# Exploring mirroredwarehouse...
# ------------------------------------------------------------
#   • mirroredwarehouse.items: ItemsOperations
#
# Exploring mlexperiment...
# ------------------------------------------------------------
#   • mlexperiment.items: ItemsOperations
#
# Exploring mlmodel...
# ------------------------------------------------------------
#   • mlmodel.endpoint: EndpointOperations
#   • mlmodel.items: ItemsOperations
#
# Exploring mounteddatafactory...
# ------------------------------------------------------------
#   • mounteddatafactory.items: ItemsOperations
#
# Exploring notebook...
# ------------------------------------------------------------
#   • notebook.items: ItemsOperations
#   • notebook.livy_sessions: LivySessionsOperations
#
# Exploring ontology...
# ------------------------------------------------------------
#   • ontology.items: ItemsOperations
#
# Exploring operationsagent...
# ------------------------------------------------------------
#   • operationsagent.items: ItemsOperations
#
# Exploring paginatedreport...
# ------------------------------------------------------------
#   • paginatedreport.items: ItemsOperations
#
# Exploring reflex...
# ------------------------------------------------------------
#   • reflex.items: ItemsOperations
#
# Exploring report...
# ------------------------------------------------------------
#   • report.items: ItemsOperations
#
# Exploring semanticmodel...
# ------------------------------------------------------------
#   • semanticmodel.items: ItemsOperations
#
# Exploring spark...
# ------------------------------------------------------------
#   • spark.custom_pools: CustomPoolsOperations
#   • spark.livy_sessions: LivySessionsOperations
#   • spark.workspace_settings: WorkspaceSettingsOperations
#
# Exploring sparkjobdefinition...
# ------------------------------------------------------------
#   • sparkjobdefinition.background_jobs: BackgroundJobsOperations
#   • sparkjobdefinition.items: ItemsOperations
#   • sparkjobdefinition.livy_sessions: LivySessionsOperations
#
# Exploring sqldatabase...
# ------------------------------------------------------------
#   • sqldatabase.items: ItemsOperations
#   • sqldatabase.mirroring: MirroringOperations
#
# Exploring sqlendpoint...
# ------------------------------------------------------------
#   • sqlendpoint.items: ItemsOperations
#   • sqlendpoint.sql_audit_settings: SQLAuditSettingsOperations
#
# Exploring userdatafunction...
# ------------------------------------------------------------
#   • userdatafunction.items: ItemsOperations
#
# Exploring variablelibrary...
# ------------------------------------------------------------
#   • variablelibrary.items: ItemsOperations
#
# Exploring warehouse...
# ------------------------------------------------------------
#   • warehouse.items: ItemsOperations
#   • warehouse.restore_points: RestorePointsOperations
#   • warehouse.restorepoints: RestorePointsOperations
#   • warehouse.sql_audit_settings: SQLAuditSettingsOperations
#
# Exploring warehousesnapshot...
# ------------------------------------------------------------
#   • warehousesnapshot.items: ItemsOperations
#
# ================================================================================
# Total modules to explore in detail: 100

# %% [markdown]
# ## Explore Each Module in Detail
#
# Document all methods across all modules in the API.

# %%
# Detailed exploration of ALL modules (not just core)
api_documentation = {
    "client": "FabricClient",
    "version": "0.1.0b2",
    "top_level_modules": list(all_top_level_modules.keys()),
    "client_methods": [],
    "all_modules": {},
}

# Document top-level client methods
print("Exploring FabricClient methods...")
print("=" * 80)

for attr_name in dir(fabric_client):
    if not attr_name.startswith("_"):
        try:
            attr = getattr(fabric_client, attr_name)
            if callable(attr):
                method_info = {
                    "name": attr_name,
                    "signature": str(inspect.signature(attr)),
                    "docstring": inspect.getdoc(attr) or "No documentation available",
                }
                api_documentation["client_methods"].append(method_info)
                print(f"  • {attr_name}{method_info['signature']}")
        except Exception as e:
            print(f"  ✗ {attr_name}: {e!s}")

print(f"\nFound {len(api_documentation['client_methods'])} client methods")

# Document all discovered modules
for module_path, module_meta in all_modules_to_explore.items():
    module_obj = module_meta["object"]

    print(f"\n{'='*80}")
    print(f"Module: fabric_client.{module_path}")
    print(f"{'='*80}")

    module_info = {"path": f"fabric_client.{module_path}", "type": module_meta["type"], "methods": [], "properties": []}

    # Get all methods and properties
    for attr_name in dir(module_obj):
        if not attr_name.startswith("_"):
            try:
                attr = getattr(module_obj, attr_name)
                if callable(attr):
                    method_info = {
                        "name": attr_name,
                        "signature": str(inspect.signature(attr)),
                        "docstring": inspect.getdoc(attr) or "No documentation available",
                    }
                    module_info["methods"].append(method_info)

                    print(f"\n  Method: {attr_name}")
                    print(f"  Signature: {method_info['signature']}")
                    if method_info["docstring"] and method_info["docstring"] != "No documentation available":
                        doc_preview = (
                            method_info["docstring"][:200] + "..."
                            if len(method_info["docstring"]) > 200
                            else method_info["docstring"]
                        )
                        print(f"  Documentation:\n    {doc_preview}")
                else:
                    # Non-callable property
                    property_info = {"name": attr_name, "type": type(attr).__name__}
                    module_info["properties"].append(property_info)

            except Exception as e:
                print(f"  ✗ Error exploring {attr_name}: {e!s}")

    api_documentation["all_modules"][module_path] = module_info

print(f"\n{'='*80}")
print("Exploration complete!")
print(f"  • Top-level modules: {len(api_documentation['top_level_modules'])}")
print(f"  • Client methods: {len(api_documentation['client_methods'])}")
print(f"  • Total sub-modules explored: {len(api_documentation['all_modules'])}")
print(f"  • Total methods found: {sum(len(m['methods']) for m in api_documentation['all_modules'].values())}")
# Out:
# Exploring FabricClient methods...
# ================================================================================
#
# Found 0 client methods
#
# ================================================================================
# Module: fabric_client.admin.domains
# ================================================================================
#
#   Method: assign_domain_workspaces_by_capacities
#   Signature: (domain_id: None, assign_domain_workspaces_by_capacities_request: None) -> None
#   Documentation:
#     Assign all workspaces that reside on the specified capacities to the specified domain.
#
# Preexisting domain assignments will be overridden unless bulk reassignment is blocked by domain
# management tenan...
#
#   Method: assign_domain_workspaces_by_ids
#   Signature: (domain_id: str, assign_domain_workspaces_by_ids_request: microsoft_fabric_api.generated.admin.models._models.AssignDomainWorkspacesByIdsRequest | IO[bytes], **kwargs: Any) -> None
#   Documentation:
#     Assign workspaces to the specified domain by workspace ID.
#
# Preexisting domain assignments will be overridden unless bulk reassignment is blocked by domain
# management tenant settings.
#
# Permissions
# ---...
#
#   Method: assign_domain_workspaces_by_principals
#   Signature: (domain_id: None, assign_domain_workspaces_by_principals_request: None) -> None
#   Documentation:
#     Assign workspaces to the specified domain, when one of the specified principals has admin
# permission in the workspace.
#
# Preexisting domain assignments will be overridden unless bulk reassignment is bl...
#
#   Method: begin_assign_domain_workspaces_by_capacities
#   Signature: (domain_id: None, assign_domain_workspaces_by_capacities_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#   Documentation:
#     Assign all workspaces that reside on the specified capacities to the specified domain.
#
# Preexisting domain assignments will be overridden unless bulk reassignment is blocked by domain
# management tenan...
#
#   Method: begin_assign_domain_workspaces_by_principals
#   Signature: (domain_id: None, assign_domain_workspaces_by_principals_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#   Documentation:
#     Assign workspaces to the specified domain, when one of the specified principals has admin
# permission in the workspace.
#
# Preexisting domain assignments will be overridden unless bulk reassignment is bl...
#
#   Method: create_domain
#   Signature: (create_domain_request: microsoft_fabric_api.generated.admin.models._models.CreateDomainRequest | IO[bytes], *, preview: bool, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.Domain
#   Documentation:
#     Creates a new domain.
#
# ..
#
#    [!NOTE]
#    This API is a release version of a preview version due to be deprecated on March 31, 2026.
#    **When calling this API - callers must set the query parameter ``...
#
#   Method: create_domain_preview
#   Signature: (create_domain_request: microsoft_fabric_api.generated.admin.models._models.CreateDomainRequest | IO[bytes], *, preview: bool, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.DomainPreview
#   Documentation:
#     Creates a new domain (preview).
#
# ..
#
#    [!NOTE]
#    This preview API will be deprecated on March 31, 2026, and replaced by a stable version,
# available `here </rest/api/fabric/admin/domains/create-domai...
#
#   Method: delete_domain
#   Signature: (domain_id: str, **kwargs: Any) -> None
#   Documentation:
#     Deletes the specified domain.
#
# Permissions
# -----------
#
# The caller must be a Fabric administrator.
#
# Required Delegated Scopes
# -------------------------
#
# Tenant.ReadWrite.All.
#
# Limitations
# -----------
# ...
#
#   Method: get_domain
#   Signature: (domain_id: str, *, preview: bool, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.Domain
#   Documentation:
#     Returns the specified domain info.
#
# ..
#
#    [!NOTE]
#    This API is a release version of a preview version due to be deprecated on March 31, 2026.
#    **When calling this API - callers must set the query...
#
#   Method: get_domain_preview
#   Signature: (domain_id: str, *, preview: bool, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.DomainPreview
#   Documentation:
#     Returns the specified domain info (preview).
#
# ..
#
#    [!NOTE]
#    This preview API will be deprecated on March 31, 2026, and replaced by a stable version,
# available `here </rest/api/fabric/admin/domains...
#
#   Method: list_domain_workspaces
#   Signature: (domain_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.DomainWorkspace')]
#   Documentation:
#     Returns a list of the workspaces assigned to the specified domain.
#
# This API supports `pagination </rest/api/fabric/articles/pagination>`_.
#
# Permissions
# -----------
#
# The caller must be a Fabric admini...
#
#   Method: list_domains
#   Signature: (*, preview: bool, non_empty_only: bool | None = None, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.DomainsResponse
#   Documentation:
#     Returns info for all domains.
#
# ..
#
#    [!NOTE]
#    This API is a release version of a preview version due to be deprecated on March 31, 2026.
#    **When calling this API - callers must set the query para...
#
#   Method: list_domains_preview
#   Signature: (*, preview: bool, non_empty_only: bool | None = None, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.DomainsResponsePreview
#   Documentation:
#     Returns info for all domains (preview).
#
# ..
#
#    [!NOTE]
#    This preview API will be deprecated on March 31, 2026, and replaced by a stable version,
# available `here </rest/api/fabric/admin/domains/list...
#
#   Method: list_role_assignments
#   Signature: (domain_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.DomainRoleAssignment')]
#   Documentation:
#     Returns a list of domain role assignments.
#
# Permissions
# -----------
#
# The caller must be a Fabric administrator.
#
# Required Delegated Scopes
# -------------------------
#
# Tenant.Read.All or Tenant.ReadWrit...
#
#   Method: role_assignments_bulk_assign
#   Signature: (domain_id: str, domain_role_assignment_request: microsoft_fabric_api.generated.admin.models._models.DomainRoleAssignmentRequest | IO[bytes], **kwargs: Any) -> None
#   Documentation:
#     Assign the specified admins or contributors to the domain.
#
# Permissions
# -----------
#
# The caller must be a Fabric administrator.
#
# Required Delegated Scopes
# -------------------------
#
# Tenant.ReadWrite.A...
#
#   Method: role_assignments_bulk_unassign
#   Signature: (domain_id: str, domain_role_unassignment_request: microsoft_fabric_api.generated.admin.models._models.DomainRoleUnassignmentRequest | IO[bytes], **kwargs: Any) -> None
#   Documentation:
#     Unassign the specified admins or contributors from the domain.
#
# Permissions
# -----------
#
# The caller must be a Fabric administrator.
#
# Required Delegated Scopes
# -------------------------
#
# Tenant.ReadWri...
#
#   Method: sync_role_assignments_to_subdomains
#   Signature: (domain_id: str, sync_role_assignments_to_subdomains_request: microsoft_fabric_api.generated.admin.models._models.SyncRoleAssignmentsToSubdomainsRequest | IO[bytes], **kwargs: Any) -> None
#   Documentation:
#     Sync the role assignments from the specified domain to its subdomains.
#
# Permissions
# -----------
#
# The caller must be a Fabric administrator.
#
# Required Delegated Scopes
# -------------------------
#
# Tenant...
#
#   Method: unassign_all_domain_workspaces
#   Signature: (domain_id: str, **kwargs: Any) -> None
#   Documentation:
#     Unassign all workspaces from the specified domain.
#
# Permissions
# -----------
#
# The caller must be a Fabric administrator.
#
# Required Delegated Scopes
# -------------------------
#
# Tenant.ReadWrite.All.
#
# Lim...
#
#   Method: unassign_domain_workspaces_by_ids
#   Signature: (domain_id: str, unassign_domain_workspaces_by_ids_request: microsoft_fabric_api.generated.admin.models._models.UnassignDomainWorkspacesByIdsRequest | IO[bytes] | None = None, **kwargs: Any) -> None
#   Documentation:
#     Unassign workspaces from the specified domain by workspace ID.
#
# Permissions
# -----------
#
# The caller must be a Fabric administrator.
#
# Required Delegated Scopes
# -------------------------
#
# Tenant.ReadWri...
#
#   Method: update_domain
#   Signature: (domain_id: str, update_domain_request: microsoft_fabric_api.generated.admin.models._models.UpdateDomainRequest | IO[bytes], *, preview: bool, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.Domain
#   Documentation:
#     Updates the specified domain info.
#
# ..
#
#    [!NOTE]
#    This API is a release version of a preview version due to be deprecated on March 31, 2026.
#    **When calling this API - callers must set the query...
#
#   Method: update_domain_preview
#   Signature: (domain_id: str, update_domain_request: microsoft_fabric_api.generated.admin.models._models.UpdateDomainRequestPreview | IO[bytes], *, preview: bool, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.DomainPreview
#   Documentation:
#     Updates the specified domain info (preview).
#
# ..
#
#    [!NOTE]
#    This preview API will be deprecated on March 31, 2026, and replaced by a stable version,
# available `here </rest/api/fabric/admin/domains...
#
# ================================================================================
# Module: fabric_client.admin.external_data_shares_provider
# ================================================================================
#
#   Method: list_external_data_shares
#   Signature: (*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ExternalDataShare')]
#   Documentation:
#     Lists the external data shares in the tenant.
#
# This API supports `pagination </rest/api/fabric/articles/pagination>`_.
#
# Permissions
# -----------
#
# The caller must be a Fabric administrator or authentica...
#
#   Method: revoke_external_data_share
#   Signature: (workspace_id: str, item_id: str, external_data_share_id: str, **kwargs: Any) -> None
#   Documentation:
#     Revokes the specified external data share. This action cannot be undone.
#
# Permissions
# -----------
#
# The caller must be a Fabric administrator.
#
# Required Delegated Scopes
# -------------------------
#
# Tena...
#
# ================================================================================
# Module: fabric_client.admin.items
# ================================================================================
#
#   Method: get_item
#   Signature: (workspace_id: str, item_id: str, *, type: str | None = None, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.Item
#   Documentation:
#     Returns the specified Fabric or PowerBI item.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based on feedback and...
#
#   Method: list_item_access_details
#   Signature: (workspace_id: str, item_id: str, *, type: str | None = None, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.ItemAccessDetailsResponse
#   Documentation:
#     Returns a list of users (including groups and service principals) and lists their workspace
# roles.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and developme...
#
#   Method: list_items
#   Signature: (*, workspace_id: str | None = None, capacity_id: str | None = None, state: str | None = None, type: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Item')]
#   Documentation:
#     Returns a list of active Fabric and PowerBI items.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based on feedbac...
#
# ================================================================================
# Module: fabric_client.admin.labels
# ================================================================================
#
#   Method: bulk_remove_labels
#   Signature: (remove_labels_request: microsoft_fabric_api.generated.admin.models._models.RemoveLabelsRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.ItemsChangeLabelResponse
#   Documentation:
#     Remove sensitivity labels from Fabric items (such as lakehouses and reports) by item ID. The
# sensitivity labels of the autogenerated items linked to the items in the call, are removed and
# their IDs ar...
#
#   Method: bulk_set_labels
#   Signature: (set_labels_request: microsoft_fabric_api.generated.admin.models._models.SetLabelsRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.ItemsChangeLabelResponse
#   Documentation:
#     Set sensitivity labels on Fabric items, such as lakehouses and reports, by item ID. The
# sensitivity labels are applied to the autogenerated items related to the requested items, and
# their IDs aren't r...
#
# ================================================================================
# Module: fabric_client.admin.sharing_links
# ================================================================================
#
#   Method: begin_bulk_remove_sharing_links
#   Signature: (bulk_remove_sharing_links_request: microsoft_fabric_api.generated.admin.models._models.BulkRemoveSharingLinksRequest | IO[bytes], **kwargs: Any) -> azure.core.polling._poller.LROPoller[microsoft_fabric_api.generated.admin.models._models.BulkRemoveSharingLinksResponse]
#   Documentation:
#     Deletes all organization sharing links for the specified Fabric items. This action cannot be
# undone.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and develop...
#
#   Method: begin_remove_all_sharing_links
#   Signature: (remove_all_sharing_links_request: microsoft_fabric_api.generated.admin.models._models.RemoveAllSharingLinksRequest | IO[bytes], **kwargs: Any) -> azure.core.polling._poller.LROPoller[NoneType]
#   Documentation:
#     Deletes all organization sharing links for all Fabric items in the tenant. This action cannot
# be undone.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and dev...
#
# ================================================================================
# Module: fabric_client.admin.sharinglinks
# ================================================================================
#
#   Method: begin_bulk_remove_sharing_links
#   Signature: (bulk_remove_sharing_links_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.admin.models._models.BulkRemoveSharingLinksResponse]
#   Documentation:
#     Deletes all organization sharing links for the specified Fabric items. This action cannot be
# undone.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and develop...
#
#   Method: begin_remove_all_sharing_links
#   Signature: (remove_all_sharing_links_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#   Documentation:
#     Deletes all organization sharing links for all Fabric items in the tenant. This action cannot
# be undone.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and dev...
#
#   Method: bulk_remove_sharing_links
#   Signature: (bulk_remove_sharing_links_request: None) -> microsoft_fabric_api.generated.admin.models._models.BulkRemoveSharingLinksResponse
#   Documentation:
#     Deletes all organization sharing links for the specified Fabric items. This action cannot be
# undone.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and develop...
#
#   Method: remove_all_sharing_links
#   Signature: (remove_all_sharing_links_request: None) -> None
#   Documentation:
#     Deletes all organization sharing links for all Fabric items in the tenant. This action cannot
# be undone.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and dev...
#
# ================================================================================
# Module: fabric_client.admin.tags
# ================================================================================
#
#   Method: bulk_create_tags
#   Signature: (create_tags_request: microsoft_fabric_api.generated.admin.models._models.CreateTagsRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.CreateTagsResponse
#   Documentation:
#     Create new tags.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based on feedback and is not recommended for produ...
#
#   Method: delete_tag
#   Signature: (tag_id: str, **kwargs: Any) -> None
#   Documentation:
#     Delete the specified tag.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based on feedback and is not recommended ...
#
#   Method: list_tags
#   Signature: (*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.AdminTagInfo')]
#   Documentation:
#     Returns a list of all the tenant's tags.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based on feedback and is n...
#
#   Method: update_tag
#   Signature: (tag_id: str, update_tag_request: microsoft_fabric_api.generated.admin.models._models.UpdateTagRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.Tag
#   Documentation:
#     Updates the specified tag.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based on feedback and is not recommended...
#
# ================================================================================
# Module: fabric_client.admin.tenants
# ================================================================================
#
#   Method: delete_capacity_tenant_setting_override
#   Signature: (capacity_id: str, tenant_setting_name: str, **kwargs: Any) -> None
#   Documentation:
#     Remove given tenant setting override for given capacity Id.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based o...
#
#   Method: list_capacities_tenant_settings_overrides
#   Signature: (*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.CapacityTenantSettingOverride')]
#   Documentation:
#     Returns list of tenant setting overrides that override at the capacities.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may ...
#
#   Method: list_capacity_tenant_settings_overrides_by_capacity_id
#   Signature: (capacity_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.CapacityTenantSetting')]
#   Documentation:
#     Returns list of tenant setting overrides that override for given capacity Id.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It ...
#
#   Method: list_domains_tenant_settings_overrides
#   Signature: (*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.DomainTenantSettingOverride')]
#   Documentation:
#     Returns list of domain delegation setting overrides.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based on feedb...
#
#   Method: list_tenant_settings
#   Signature: (*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.TenantSetting')]
#   Documentation:
#     Returns a list of the tenant settings.
#
# Permissions
# -----------
#
# The caller must be a Fabric administrator or authenticate using a service principal.
#
# Required Delegated Scopes
# -----------------------...
#
#   Method: list_workspaces_tenant_settings_overrides
#   Signature: (*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.WorkspaceTenantSettingOverride')]
#   Documentation:
#     Returns list of workspace delegation setting overrides.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based on fe...
#
#   Method: update_capacity_tenant_setting_override
#   Signature: (capacity_id: str, tenant_setting_name: str, update_tenant_setting_override_request: microsoft_fabric_api.generated.admin.models._models.UpdateCapacityTenantSettingOverrideRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.UpdateCapacityTenantSettingOverrideResponse
#   Documentation:
#     Update given tenant setting override for given capacity Id.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based o...
#
#   Method: update_tenant_setting
#   Signature: (tenant_setting_name: str, update_tenant_setting_request: microsoft_fabric_api.generated.admin.models._models.UpdateTenantSettingRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.UpdateTenantSettingResponse
#   Documentation:
#     Update a given tenant setting.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based on feedback and is not recomme...
#
# ================================================================================
# Module: fabric_client.admin.users
# ================================================================================
#
#   Method: list_access_entities
#   Signature: (user_id: str, *, type: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.AccessEntity')]
#   Documentation:
#     Returns a list of permission details for Fabric and PowerBI items the specified user can
# access.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development...
#
# ================================================================================
# Module: fabric_client.admin.workspaces
# ================================================================================
#
#   Method: get_workspace
#   Signature: (workspace_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.Workspace
#   Documentation:
#     Returns the specified workspace.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based on feedback and is not recom...
#
#   Method: list_git_connections
#   Signature: (*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.GitConnectionDetails')]
#   Documentation:
#     Returns a list of Git connections.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based on feedback and is not rec...
#
#   Method: list_networking_communication_policies
#   Signature: (*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.NetworkCommunicationPolicyDetails')]
#   Documentation:
#     Returns network communication policy settings for list of workspaces enabled with either
# Inbound or Outbound Access Protection.
#
# This API supports `pagination </rest/api/fabric/articles/pagination>`_ ...
#
#   Method: list_workspace_access_details
#   Signature: (workspace_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.WorkspaceAccessDetailsResponse
#   Documentation:
#     Returns a list of users (including groups and ServicePrincipals) that have access to the
# specified workspace.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation an...
#
#   Method: list_workspaces
#   Signature: (*, type: str | None = None, capacity_id: str | None = None, name: str | None = None, state: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Workspace')]
#   Documentation:
#     Returns a list of workspaces.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based on feedback and is not recommen...
#
#   Method: restore_workspace
#   Signature: (workspace_id: str, restore_workspace_request: microsoft_fabric_api.generated.admin.models._models.RestoreWorkspaceRequest | IO[bytes], **kwargs: Any) -> None
#   Documentation:
#     Restores a deleted workspace.
#
# ..
#
#    [!NOTE]
#    This API is part of a Preview release and is provided for evaluation and development
# purposes only. It may change based on feedback and is not recommen...
#
# ================================================================================
# Module: fabric_client.anomalydetector.items
# ================================================================================
#
#   Method: begin_create_anomaly_detector
#   Signature: (workspace_id: None, create_anomaly_detector_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.anomalydetector.models._models.AnomalyDetector]
#   Documentation:
#     Creates a AnomalyDetector in the specified workspace.
#
# ..
#
#    [!NOTE]
#    AnomalyDetector item is currently in Preview (\ `learn more
# </fabric/fundamentals/preview>`_\ ).
#
#
# This API supports `long runn...
#
#   Method: begin_get_anomaly_detector_definition
#   Signature: (workspace_id: None, anomaly_detector_id: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.anomalydetector.models._models.AnomalyDetectorDefinitionResponse]
#   Documentation:
#     Returns the specified AnomalyDetector definition.
#
# ..
#
#    [!NOTE]
#    AnomalyDetector item is currently in Preview (\ `learn more
# </fabric/fundamentals/preview>`_\ ).
#
#
# This API supports `long running ...
#
#   Method: begin_update_anomaly_detector_definition
#   Signature: (workspace_id: None, anomaly_detector_id: None, update_anomaly_detector_definition_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#   Documentation:
#     Overrides the definition for the specified AnomalyDetector.
#
# ..
#
#    [!NOTE]
#    AnomalyDetector item is currently in Preview (\ `learn more
# </fabric/fundamentals/preview>`_\ ).
#
#
# This API supports `lon...
#
#   Method: create_anomaly_detector
#   Signature: (workspace_id: None, create_anomaly_detector_request: None) -> microsoft_fabric_api.generated.anomalydetector.models._models.AnomalyDetector
#   Documentation:
#     Creates a AnomalyDetector in the specified workspace.
#
# ..
#
#    [!NOTE]
#    AnomalyDetector item is currently in Preview (\ `learn more
# </fabric/fundamentals/preview>`_\ ).
#
#
# This API supports `long runn...
#
#   Method: delete_anomaly_detector
#   Signature: (workspace_id: str, anomaly_detector_id: str, **kwargs: Any) -> None
#   Documentation:
#     Deletes the specified AnomalyDetector.
#
# ..
#
#    [!NOTE]
#    AnomalyDetector item is currently in Preview (\ `learn more
# </fabric/fundamentals/preview>`_\ ).
#
#
# Permissions
# -----------
#
#  The caller must h...
#
#   Method: get_anomaly_detector
#   Signature: (workspace_id: str, anomaly_detector_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.anomalydetector.models._models.AnomalyDetector
#   Documentation:
#     Returns properties of the specified AnomalyDetector.
#
# ..
#
#    [!NOTE]
#    AnomalyDetector item is currently in Preview (\ `learn more
# </fabric/fundamentals/preview>`_\ ).
#
#
# Permissions
# -----------
#
#  The...
#
#   Method: get_anomaly_detector_definition
#   Signature: (workspace_id: None, anomaly_detector_id: None) -> microsoft_fabric_api.generated.anomalydetector.models._models.AnomalyDetectorDefinitionResponse
#   Documentation:
#     Returns the specified AnomalyDetector definition.
#
# ..
#
#    [!NOTE]
#    AnomalyDetector item is currently in Preview (\ `learn more
# </fabric/fundamentals/preview>`_\ ).
#
#
# This API supports `long running ...
#
#   Method: list_anomaly_detectors
#   Signature: (workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.AnomalyDetector')]
#   Documentation:
#     Returns a list of AnomalyDetectors from the specified workspace.
#
# ..
#
#    [!NOTE]
#    AnomalyDetector item is currently in Preview (\ `learn more
# </fabric/fundamentals/preview>`_\ ).
#
#
# This API supports...
#
#   Method: update_anomaly_detector
#   Signature: (workspace_id: str, anomaly_detector_id: str, update_anomaly_detector_request: microsoft_fabric_api.generated.anomalydetector.models._models.UpdateAnomalyDetectorRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.anomalydetector.models._models.AnomalyDetector
#   Documentation:
#     Updates the properties of the specified AnomalyDetector.
#
# ..
#
#    [!NOTE]
#    AnomalyDetector item is currently in Preview (\ `learn more
# </fabric/fundamentals/preview>`_\ ).
#
#
# Permissions
# -----------
#
# ...
#
#   Method: update_anomaly_detector_definition
#   Signature: (workspace_id: None, anomaly_detector_id: None, update_anomaly_detector_definition_request: None) -> None
#   Documentation:
#     Overrides the definition for the specified AnomalyDetector.
#
# ..
#
#    [!NOTE]
#    AnomalyDetector item is currently in Preview (\ `learn more
# </fabric/fundamentals/preview>`_\ ).
#
#
# This API supports `lon...
#
# ================================================================================
# Module: fabric_client.apacheairflowjob.files
# ================================================================================
#
#   Method: create_or_update_apache_airflow_job_file_beta
#   Signature: (workspace_id: str, apache_airflow_job_id: str, file_path: str, file_contents: IO[bytes], *, beta: bool = True, **kwargs: Any) -> None
#   Documentation:
#     Creates or updates an Apache Airflow job file.
#
# ..
#
#    [!NOTE]
#    This API is part of a Beta release and is provided for evaluation and development purposes
# only. It may change based on feedback and i...
#
#   Method: delete_apache_airflow_job_file_beta
#   Signature: (workspace_id: str, apache_airflow_job_id: str, file_path: str, *, beta: bool = True, **kwargs: Any) -> None
#   Documentation:
#     Deletes the specified Apache Airflow job file.
#
# ..
#
#    [!NOTE]
#    This API is part of a Beta release and is provided for evaluation and development purposes
# only. It may change based on feedback and i...
#
#   Method: get_apache_airflow_job_file_beta
#   Signature: (workspace_id: str, apache_airflow_job_id: str, file_path: str, *, beta: bool = True, **kwargs: Any) -> Iterator[bytes]
#   Documentation:
#     Returns the specified Apache Airflow job file.
#
# ..
#
#    [!NOTE]
#    This API is part of a Beta release and is provided for evaluation and development purposes
# only. It may change based on feedback and i...
#
#   Method: list_apache_airflow_job_files_beta
#   Signature: (workspace_id: str, apache_airflow_job_id: str, *, root_path: str | None = None, beta: bool = True, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ApacheAirflowJobFileMetadata')]
#   Documentation:
#     Returns a list of Apache Airflow job files from the specified Apache Airflow job.
#
# ..
#
#    [!NOTE]
#    This API is part of a Beta release and is provided for evaluation and development purposes
# only. It...
#
# ================================================================================
# Module: fabric_client.apacheairflowjob.items
# ================================================================================
#
#   Method: begin_create_apache_airflow_job
#   Signature: (workspace_id: None, create_apache_airflow_job_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.apacheairflowjob.models._models.ApacheAirflowJob]
#   Documentation:
#     Creates an Apache Airflow job in the specified workspace.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
#  To create Apache Airflow job with a ...
#
#   Method: begin_get_apache_airflow_job_definition
#   Signature: (workspace_id: None, apache_airflow_job_id: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.apacheairflowjob.models._models.ApacheAirflowJobDefinitionResponse]
#   Documentation:
#     Returns the specified Apache Airflow job public definition.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# When you get a 's public definition...
#
#   Method: begin_update_apache_airflow_job_definition
#   Signature: (workspace_id: None, apache_airflow_job_id: None, update_apache_airflow_job_definition_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#   Documentation:
#     Overrides the definition for the specified Apache Airflow job.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# Updating the 's definition, does...
#
#   Method: create_apache_airflow_job
#   Signature: (workspace_id: None, create_apache_airflow_job_request: None) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.ApacheAirflowJob
#   Documentation:
#     Creates an Apache Airflow job in the specified workspace.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
#  To create Apache Airflow job with a ...
#
#   Method: delete_apache_airflow_job
#   Signature: (workspace_id: str, apache_airflow_job_id: str, **kwargs: Any) -> None
#   Documentation:
#     Deletes the specified Apache Airflow job.
#
# Permissions
# -----------
#
#  The caller must have *write* permissions for the Apache Airflow job.
#
# Required Delegated Scopes
# -------------------------
#
#  ApacheA...
#
#   Method: get_apache_airflow_job
#   Signature: (workspace_id: str, apache_airflow_job_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.ApacheAirflowJob
#   Documentation:
#     Returns properties of the specified Apache Airflow job.
#
# Permissions
# -----------
#
#  The caller must have *read* permissions for the Apache Airflow job.
#
# Required Delegated Scopes
# ----------------------...
#
#   Method: get_apache_airflow_job_definition
#   Signature: (workspace_id: None, apache_airflow_job_id: None) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.ApacheAirflowJobDefinitionResponse
#   Documentation:
#     Returns the specified Apache Airflow job public definition.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# When you get a 's public definition...
#
#   Method: list_apache_airflow_jobs
#   Signature: (workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ApacheAirflowJob')]
#   Documentation:
#     Returns a list of Apache Airflow jobs from the specified workspace.
#
# This API supports `pagination </rest/api/fabric/articles/pagination>`_.
#
# Permissions
# -----------
#
#  The caller must have a *viewer* ...
#
#   Method: update_apache_airflow_job
#   Signature: (workspace_id: str, apache_airflow_job_id: str, update_apache_airflow_job_request: microsoft_fabric_api.generated.apacheairflowjob.models._models.UpdateApacheAirflowJobRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.ApacheAirflowJob
#   Documentation:
#     Updates the properties of the specified Apache Airflow job.
#
# Permissions
# -----------
#
#  The caller must have *read and write* permissions for the apache airflow job.
#
# Required Delegated Scopes
# --------...
#
#   Method: update_apache_airflow_job_definition
#   Signature: (workspace_id: None, apache_airflow_job_id: None, update_apache_airflow_job_definition_request: None) -> None
#   Documentation:
#     Overrides the definition for the specified Apache Airflow job.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# Updating the 's definition, does...
#
# ================================================================================
# Module: fabric_client.apacheairflowjob.pool_management
# ================================================================================
#
#   Method: create_airflow_pool_template_beta
#   Signature: (workspace_id: str, create_airflow_pool_template_request: microsoft_fabric_api.generated.apacheairflowjob.models._models.CreateAirflowPoolTemplateRequest | IO[bytes], *, beta: bool = True, **kwargs: Any) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.AirflowPoolTemplate
#   Documentation:
#     Create an Apache Airflow pool template.
#
# ..
#
#    [!NOTE]
#    This API is part of a Beta release and is provided for evaluation and development purposes
# only. It may change based on feedback and is not r...
#
#   Method: delete_airflow_pool_template_beta
#   Signature: (workspace_id: str, pool_template_id: str, *, beta: bool = True, **kwargs: Any) -> None
#   Documentation:
#     Delete an Apache Airflow pool template.
#
# ..
#
#    [!NOTE]
#    This API is part of a Beta release and is provided for evaluation and development purposes
# only. It may change based on feedback and is not r...
#
#   Method: get_airflow_pool_template_beta
#   Signature: (workspace_id: str, pool_template_id: str, *, beta: bool = True, **kwargs: Any) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.AirflowPoolTemplate
#   Documentation:
#     Get an Apache Airflow pool template.
#
# ..
#
#    [!NOTE]
#    This API is part of a Beta release and is provided for evaluation and development purposes
# only. It may change based on feedback and is not reco...
#
#   Method: list_airflow_pool_templates_beta
#   Signature: (workspace_id: str, *, continuation_token_parameter: str | None = None, beta: bool = True, **kwargs: Any) -> Iterable[ForwardRef('_models.AirflowPoolTemplate')]
#   Documentation:
#     List Apache Airflow pool templates.
#
# ..
#
#    [!NOTE]
#    This API is part of a Beta release and is provided for evaluation and development purposes
# only. It may change based on feedback and is not recom...
#
# ================================================================================
# Module: fabric_client.apacheairflowjob.workspace_settings
# ================================================================================
#
#   Method: get_airflow_workspace_settings_beta
#   Signature: (workspace_id: str, *, beta: bool = True, **kwargs: Any) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.AirflowWorkspaceSettings
#   Documentation:
#     Get Apache Airflow workspace settings.
#
# ..
#
#    [!NOTE]
#    This API is part of a Beta release and is provided for evaluation and development purposes
# only. It may change based on feedback and is not re...
#
#   Method: update_airflow_workspace_settings_beta
#   Signature: (workspace_id: str, update_airflow_workspace_settings_request: microsoft_fabric_api.generated.apacheairflowjob.models._models.UpdateAirflowWorkspaceSettingsRequest | IO[bytes], *, beta: bool = True, **kwargs: Any) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.AirflowWorkspaceSettings
#   Documentation:
#     Update Apache Airflow workspace settings.
#
# ..
#
#    [!NOTE]
#    This API is part of a Beta release and is provided for evaluation and development purposes
# only. It may change based on feedback and is not...
#
# ================================================================================
# Module: fabric_client.copyjob.items
# ================================================================================
#
#   Method: begin_create_copy_job
#   Signature: (workspace_id: None, create_copy_job_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.copyjob.models._models.CopyJob]
#   Documentation:
#     Creates a CopyJob in the specified workspace.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
#  To create CopyJob with a public definition, refe...
#
#   Method: begin_get_copy_job_definition
#   Signature: (workspace_id: None, copy_job_id: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.copyjob.models._models.CopyJobDefinitionResponse]
#   Documentation:
#     Returns the specified CopyJob public definition.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# When you get a CopyJob's public definition, th...
#
#   Method: begin_update_copy_job_definition
#   Signature: (workspace_id: None, copy_job_id: None, update_copy_job_definition_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#   Documentation:
#     Overrides the definition for the specified CopyJob.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# Updating the CopyJob's definition, does not...
#
#   Method: create_copy_job
#   Signature: (workspace_id: None, create_copy_job_request: None) -> microsoft_fabric_api.generated.copyjob.models._models.CopyJob
#   Documentation:
#     Creates a CopyJob in the specified workspace.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
#  To create CopyJob with a public definition, refe...
#
#   Method: delete_copy_job
#   Signature: (workspace_id: str, copy_job_id: str, **kwargs: Any) -> None
#   Documentation:
#     Deletes the specified CopyJob.
#
# Permissions
# -----------
#
#  The caller must have *write* permissions for the copy job.
#
# Required Delegated Scopes
# -------------------------
#
#  CopyJob.ReadWrite.All or Ite...
#
#   Method: get_copy_job
#   Signature: (workspace_id: str, copy_job_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.copyjob.models._models.CopyJob
#   Documentation:
#     Returns properties of the specified CopyJob.
#
# Permissions
# -----------
#
#  The caller must have *read* permissions for the copy job.
#
# Required Delegated Scopes
# -------------------------
#
#  CopyJob.Read.Al...
#
#   Method: get_copy_job_definition
#   Signature: (workspace_id: None, copy_job_id: None) -> microsoft_fabric_api.generated.copyjob.models._models.CopyJobDefinitionResponse
#   Documentation:
#     Returns the specified CopyJob public definition.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# When you get a CopyJob's public definition, th...
#
#   Method: list_copy_jobs
#   Signature: (workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.CopyJob')]
#   Documentation:
#     Returns a list of CopyJobs from the specified workspace.
#
# This API supports `pagination </rest/api/fabric/articles/pagination>`_.
#
# Permissions
# -----------
#
#  The caller must have a *viewer* workspace r...
#
#   Method: update_copy_job
#   Signature: (workspace_id: str, copy_job_id: str, update_copy_job_request: microsoft_fabric_api.generated.copyjob.models._models.UpdateCopyJobRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.copyjob.models._models.CopyJob
#   Documentation:
#     Updates the properties of the specified CopyJob.
#
# Permissions
# -----------
#
#  The caller must have *read and write* permissions for the copy job.
#
# Required Delegated Scopes
# -------------------------
#
#  C...
#
#   Method: update_copy_job_definition
#   Signature: (workspace_id: None, copy_job_id: None, update_copy_job_definition_request: None) -> None
#   Documentation:
#     Overrides the definition for the specified CopyJob.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# Updating the CopyJob's definition, does not...
#
# ================================================================================
# Module: fabric_client.core.capacities
# ================================================================================
#
#   Method: list_capacities
#   Signature: (*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Capacity')]
#   Documentation:
#     Returns a list of capacities the principal can access (either administrator or a contributor).
#
# This API supports `pagination </rest/api/fabric/articles/pagination>`_.
#
# Required Delegated Scopes
# -----...
#
# ================================================================================
# Module: fabric_client.core.connections
# ================================================================================
#
#   Method: add_connection_role_assignment
#   Signature: (connection_id: str, add_connection_role_assignment_request: microsoft_fabric_api.generated.core.models._models.AddConnectionRoleAssignmentRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.ConnectionRoleAssignment
#   Documentation:
#     Adds a connection role assignment.
#
# To get the principal user ID required for request body, see `Find the user ID
# </partner-center/find-ids-and-domain-names#find-the-user-object-id>`_.
#
# Permissions
# --...
#
#   Method: create_connection
#   Signature: (create_connection_request: microsoft_fabric_api.generated.core.models._models.CreateConnectionRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Connection
#   Documentation:
#     Creates a connection.
#
# To encrypt credentials, see `Configure credentials programmatically
# </power-bi/developer/embedded/configure-credentials>`_.
#
# Permissions
# -----------
#
#
# * If creating a gateway co...
#
#   Method: delete_connection
#   Signature: (connection_id: str, **kwargs: Any) -> None
#   Documentation:
#     Delete connection by ID.
#
# Permissions
# -----------
#
# The caller must have owner permission for the connection or admin permission for the gateway of
# the connection.
#
# Required Delegated Scopes
# ----------...
#
#   Method: delete_connection_role_assignment
#   Signature: (connection_id: str, connection_role_assignment_id: str, **kwargs: Any) -> None
#   Documentation:
#     Delete the specified role assignment for the connection.
#
# To get the principal user ID required for request body, see `Find the user ID
# </partner-center/find-ids-and-domain-names#find-the-user-object-...
#
#   Method: get_connection
#   Signature: (connection_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Connection
#   Documentation:
#     Get connection by ID.
#
# Permissions
# -----------
#
# The caller must have permission for the connection or admin permission for the gateway of the
# connection.
#
# Required Delegated Scopes
# -------------------...
#
#   Method: get_connection_role_assignment
#   Signature: (connection_id: str, connection_role_assignment_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.ConnectionRoleAssignment
#   Documentation:
#     Returns the principal's role assignment for the connection.
#
# To get the principal user ID required for request body, see `Find the user ID
# </partner-center/find-ids-and-domain-names#find-the-user-obje...
#
#   Method: list_connection_role_assignments
#   Signature: (connection_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ConnectionRoleAssignment')]
#   Documentation:
#     Returns a list of connection role assignments.
#
# This API supports `pagination </rest/api/fabric/articles/pagination>`_.
#
# Permissions
# -----------
#
#
# * The caller must have *User* or higher role on the c...
#
#   Method: list_connections
#   Signature: (*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Connection')]
#   Documentation:
#     Returns a list of on-premises, virtual network and cloud connections the user has permission
# for.
#
# Permissions
# -----------
#
# The caller must have permission for the connection.
#
# Required Delegated Scop...
#
#   Method: list_supported_connection_types
#   Signature: (*, gateway_id: str | None = None, show_all_creation_methods: bool | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ConnectionCreationMetadata')]
#   Documentation:
#     Lists supported connection types.
#
# Permissions
# -----------
#
# ...
# </rest/api/fabric/articles/long-running-operation>`_.
#
# When you get a VariableLibrary's publ...
#
#   Method: list_variable_libraries
#   Signature: (workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.VariableLibrary')]
#   Documentation:
#     Returns a list of variable libraries from the specified workspace.
#
# This API supports `pagination </rest/api/fabric/articles/pagination>`_.
#
# Permissions
# -----------
#
# The caller must have a *viewer* wo...
#
#   Method: update_variable_library
#   Signature: (workspace_id: str, variable_library_id: str, update_variable_library_request: microsoft_fabric_api.generated.variablelibrary.models._models.UpdateVariableLibraryRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.variablelibrary.models._models.VariableLibrary
#   Documentation:
#     Updates the properties of the specified variable library.
#
# Permissions
# -----------
#
# The caller must have *read and write* permissions for the variable library.
#
# Required Delegated Scopes
# -------------...
#
#   Method: update_variable_library_definition
#   Signature: (workspace_id: None, variable_library_id: None, update_variable_library_definition_request: None) -> None
#   Documentation:
#     Overrides the definition for the specified variable library.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# Updating the VariableLibrary's def...
#
# ================================================================================
# Module: fabric_client.warehouse.items
# ================================================================================
#
#   Method: begin_create_warehouse
#   Signature: (workspace_id: None, create_warehouse_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.warehouse.models._models.Warehouse]
#   Documentation:
#     Creates a warehouse in the specified workspace.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
#  This API does not support create a warehouse w...
#
#   Method: create_warehouse
#   Signature: (workspace_id: None, create_warehouse_request: None) -> microsoft_fabric_api.generated.warehouse.models._models.Warehouse
#   Documentation:
#     Creates a warehouse in the specified workspace.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
#  This API does not support create a warehouse w...
#
#   Method: delete_warehouse
#   Signature: (workspace_id: str, warehouse_id: str, **kwargs: Any) -> None
#   Documentation:
#     Deletes the specified warehouse.
#
# Permissions
# -----------
#
# The caller must have *write* permissions for the warehouse.
#
# Required Delegated Scopes
# -------------------------
#
#  Warehouse.ReadWrite.All or...
#
#   Method: get_connection_string
#   Signature: (workspace_id: str, warehouse_id: str, *, guest_tenant_id: str | None = None, private_link_type: str | microsoft_fabric_api.generated.warehouse.models._enums.PrivateLinkType | None = None, **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.ConnectionStringResponse
#   Documentation:
#     Returns the SQL connection string of the specified warehouse.
#
# Permissions
# -----------
#
#  The caller must have *read* permissions for the warehouse. The caller must have *viewer* or
# higher workspace ro...
#
#   Method: get_warehouse
#   Signature: (workspace_id: str, warehouse_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.Warehouse
#   Documentation:
#     Returns properties of the specified warehouse.
#
# Permissions
# -----------
#
# The caller must have *read* permissions for the warehouse.
#
# Required Delegated Scopes
# -------------------------
#
#  Warehouse.Rea...
#
#   Method: list_warehouses
#   Signature: (workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Warehouse')]
#   Documentation:
#     Returns a list of warehouses from the specified workspace.
#
# This API supports `pagination </rest/api/fabric/articles/pagination>`_.
#
# Permissions
# -----------
#
# The caller must have a *viewer* workspace ...
#
#   Method: update_warehouse
#   Signature: (workspace_id: str, warehouse_id: str, update_warehouse_request: microsoft_fabric_api.generated.warehouse.models._models.UpdateWarehouseRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.Warehouse
#   Documentation:
#     Updates the properties of the specified warehouse.
#
# Permissions
# -----------
#
# The caller must have *read and write* permissions for the warehouse.
#
# Required Delegated Scopes
# -------------------------
#
# ...
#
# ================================================================================
# Module: fabric_client.warehouse.restore_points
# ================================================================================
#
#   Method: begin_create_restore_point
#   Signature: (workspace_id: str, warehouse_id: str, create_restore_point_request: microsoft_fabric_api.generated.warehouse.models._models.CreateRestorePointRequest | IO[bytes], **kwargs: Any) -> azure.core.polling._poller.LROPoller[microsoft_fabric_api.generated.warehouse.models._models.RestorePoint]
#   Documentation:
#     Creates a restore point for a warehouse at the current timestamp.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# Permissions
# -----------
#
#  The...
#
#   Method: begin_restore_to_restore_point
#   Signature: (workspace_id: str, warehouse_id: str, restore_point_id: str, **kwargs: Any) -> azure.core.polling._poller.LROPoller[NoneType]
#   Documentation:
#     Restores a warehouse in-place to the restore point specified.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# Permissions
# -----------
#
#  The cal...
#
#   Method: delete_restore_point
#   Signature: (workspace_id: str, warehouse_id: str, restore_point_id: str, **kwargs: Any) -> None
#   Documentation:
#     Deletes a restore point specified for a warehouse.
#
# Permissions
# -----------
#
#  The caller must have *write* warehouse permission.
#
# Required Delegated Scopes
# -------------------------
#
# Warehouse.ReadWri...
#
#   Method: get_restore_point
#   Signature: (workspace_id: str, warehouse_id: str, restore_point_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.RestorePoint
#   Documentation:
#     Returns the properties of a restore point specified for a warehouse.
#
# Permissions
# -----------
#
#  The caller must have *read* or *write* warehouse permission.
#
# Required Delegated Scopes
# ----------------...
#
#   Method: list_restore_points
#   Signature: (workspace_id: str, warehouse_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.RestorePoint')]
#   Documentation:
#     Returns all restore points for a warehouse.
#
# This API supports `pagination </rest/api/fabric/articles/pagination>`_.
#
# Permissions
# -----------
#
#  The caller must have *read* or *write* warehouse permiss...
#
#   Method: update_restore_point
#   Signature: (workspace_id: str, warehouse_id: str, restore_point_id: str, update_restore_point_request: microsoft_fabric_api.generated.warehouse.models._models.UpdateRestorePointRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.RestorePoint
#   Documentation:
#     Updates an existing restore point by renaming the name or description of it.
#
# Permissions
# -----------
#
#  The caller must have *write* warehouse permission.
#
# Required Delegated Scopes
# ------------------...
#
# ================================================================================
# Module: fabric_client.warehouse.restorepoints
# ================================================================================
#
#   Method: begin_create_restore_point
#   Signature: (workspace_id: None, warehouse_id: None, create_restore_point_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.warehouse.models._models.RestorePoint]
#   Documentation:
#     Creates a restore point for a warehouse at the current timestamp.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# Permissions
# -----------
#
#  The...
#
#   Method: begin_restore_to_restore_point
#   Signature: (workspace_id: None, warehouse_id: None, restore_point_id: None) -> azure.core.polling._poller.LROPoller[NoneType]
#   Documentation:
#     Restores a warehouse in-place to the restore point specified.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# Permissions
# -----------
#
#  The cal...
#
#   Method: create_restore_point
#   Signature: (workspace_id: None, warehouse_id: None, create_restore_point_request: None) -> microsoft_fabric_api.generated.warehouse.models._models.RestorePoint
#   Documentation:
#     Creates a restore point for a warehouse at the current timestamp.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# Permissions
# -----------
#
#  The...
#
#   Method: delete_restore_point
#   Signature: (workspace_id: str, warehouse_id: str, restore_point_id: str, **kwargs: Any) -> None
#   Documentation:
#     Deletes a restore point specified for a warehouse.
#
# Permissions
# -----------
#
#  The caller must have *write* warehouse permission.
#
# Required Delegated Scopes
# -------------------------
#
# Warehouse.ReadWri...
#
#   Method: get_restore_point
#   Signature: (workspace_id: str, warehouse_id: str, restore_point_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.RestorePoint
#   Documentation:
#     Returns the properties of a restore point specified for a warehouse.
#
# Permissions
# -----------
#
#  The caller must have *read* or *write* warehouse permission.
#
# Required Delegated Scopes
# ----------------...
#
#   Method: list_restore_points
#   Signature: (workspace_id: str, warehouse_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.RestorePoint')]
#   Documentation:
#     Returns all restore points for a warehouse.
#
# This API supports `pagination </rest/api/fabric/articles/pagination>`_.
#
# Permissions
# -----------
#
#  The caller must have *read* or *write* warehouse permiss...
#
#   Method: restore_to_restore_point
#   Signature: (workspace_id: None, warehouse_id: None, restore_point_id: None) -> None
#   Documentation:
#     Restores a warehouse in-place to the restore point specified.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# Permissions
# -----------
#
#  The cal...
#
#   Method: update_restore_point
#   Signature: (workspace_id: str, warehouse_id: str, restore_point_id: str, update_restore_point_request: microsoft_fabric_api.generated.warehouse.models._models.UpdateRestorePointRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.RestorePoint
#   Documentation:
#     Updates an existing restore point by renaming the name or description of it.
#
# Permissions
# -----------
#
#  The caller must have *write* warehouse permission.
#
# Required Delegated Scopes
# ------------------...
#
# ================================================================================
# Module: fabric_client.warehouse.sql_audit_settings
# ================================================================================
#
#   Method: get_sql_audit_settings
#   Signature: (workspace_id: str, item_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.SqlAuditSettings
#   Documentation:
#     Returns the settings associated with the warehouse.
#
# Permissions
# -----------
#
#  The caller must have *reader* or higher item permission.
#
# Required Delegated Scopes
# -------------------------
#
# Warehouse....
#
#   Method: set_audit_actions_and_groups
#   Signature: (workspace_id: str, item_id: str, set_audit_actions_and_groups_request: List[str] | IO[bytes], **kwargs: Any) -> None
#   Documentation:
#     Update the audit actions and groups for this warehouse.
#
# Permissions
# -----------
#
#  The caller must have *audit* item permission.
#
# Required Delegated Scopes
# -------------------------
#
# Item.Audit.All
#
# M...
#
#   Method: update_sql_audit_settings
#   Signature: (workspace_id: str, item_id: str, update_audit_settings_request: microsoft_fabric_api.generated.warehouse.models._models.SqlAuditSettingsUpdate | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.SqlAuditSettings
#   Documentation:
#     Update settings associated with the warehouse.
#
# Permissions
# -----------
#
#  The caller must have *audit* item permission.
#
# Required Delegated Scopes
# -------------------------
#
# Item.Audit.All
#
# Microsoft ...
#
# ================================================================================
# Module: fabric_client.warehousesnapshot.items
# ================================================================================
#
#   Method: begin_create_warehouse_snapshot
#   Signature: (workspace_id: None, create_warehouse_snapshot_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.warehousesnapshot.models._models.WarehouseSnapshot]
#   Documentation:
#     Creates a Warehouse snapshot in the specified workspace.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# Permissions
# -----------
#
#  The caller m...
#
#   Method: create_warehouse_snapshot
#   Signature: (workspace_id: None, create_warehouse_snapshot_request: None) -> microsoft_fabric_api.generated.warehousesnapshot.models._models.WarehouseSnapshot
#   Documentation:
#     Creates a Warehouse snapshot in the specified workspace.
#
# This API supports `long running operations (LRO)
# </rest/api/fabric/articles/long-running-operation>`_.
#
# Permissions
# -----------
#
#  The caller m...
#
#   Method: delete_warehouse_snapshot
#   Signature: (workspace_id: str, warehouse_snapshot_id: str, **kwargs: Any) -> None
#   Documentation:
#     Deletes the specified Warehouse snapshot.
#
# Permissions
# -----------
#
#  The caller must have *write* permissions for the warehouse snapshot.
#
# Required Delegated Scopes
# -------------------------
#
#  Warehou...
#
#   Method: get_warehouse_snapshot
#   Signature: (workspace_id: str, warehouse_snapshot_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.warehousesnapshot.models._models.WarehouseSnapshot
#   Documentation:
#     Returns properties of the specified Warehouse snapshot.
#
# Permissions
# -----------
#
#  The caller must have *read* permissions for the warehouse snapshot.
#
# Required Delegated Scopes
# ----------------------...
#
#   Method: list_warehouse_snapshots
#   Signature: (workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.WarehouseSnapshot')]
#   Documentation:
#     Returns a list of Warehouse snapshots from the specified workspace.
#
# This API supports `pagination </rest/api/fabric/articles/pagination>`_.
#
# Permissions
# -----------
#
#  The caller must have a *viewer* ...
#
#   Method: update_warehouse_snapshot
#   Signature: (workspace_id: str, warehouse_snapshot_id: str, update_warehouse_snapshot_request: microsoft_fabric_api.generated.warehousesnapshot.models._models.UpdateWarehouseSnapshotRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.warehousesnapshot.models._models.WarehouseSnapshot
#   Documentation:
#     Updates the properties of the specified Warehouse snapshot.
#
# Permissions
# -----------
#
#  The caller must have *read and write* permissions for the warehouse snapshot.
#
# Required Delegated Scopes
# --------...
#
# ================================================================================
# Exploration complete!
#   • Top-level modules: 44
#   • Client methods: 0
#   • Total sub-modules explored: 100
#   • Total methods found: 705

# %% [markdown]
# ## Export API Documentation to JSON

# %%
# Save to JSON file
output_file = "fabric-api-complete-documentation.json"

with open(output_file, "w", encoding="utf-8") as f:
    json.dump(api_documentation, f, indent=2, ensure_ascii=False)

print(f"✓ Complete API documentation saved to {output_file}")
print("\nSummary:")
print(f"  • Top-level modules: {len(api_documentation['top_level_modules'])}")
print(f"  • Client methods: {len(api_documentation['client_methods'])}")
print(f"  • Total sub-modules: {len(api_documentation['all_modules'])}")

total_methods = sum(len(m["methods"]) for m in api_documentation["all_modules"].values())
print(f"  • Total methods: {total_methods + len(api_documentation['client_methods'])}")

print("\nBy module:")
for module_path, module_info in sorted(api_documentation["all_modules"].items()):
    print(f"  • {module_path}: {len(module_info['methods'])} methods, {len(module_info['properties'])} properties")
# Out:
# ✓ Complete API documentation saved to fabric-api-complete-documentation.json
#
# Summary:
#   • Top-level modules: 44
#   • Client methods: 0
#   • Total sub-modules: 100
#   • Total methods: 705
#
# By module:
#   • admin.domains: 21 methods, 1 properties
#   • admin.external_data_shares_provider: 2 methods, 1 properties
#   • admin.items: 3 methods, 1 properties
#   • admin.labels: 2 methods, 1 properties
#   • admin.sharing_links: 2 methods, 1 properties
#   • admin.sharinglinks: 4 methods, 1 properties
#   • admin.tags: 4 methods, 1 properties
#   • admin.tenants: 8 methods, 1 properties
#   • admin.users: 1 methods, 1 properties
#   • admin.workspaces: 6 methods, 1 properties
#   • anomalydetector.items: 10 methods, 1 properties
#   • apacheairflowjob.files: 4 methods, 1 properties
#   • apacheairflowjob.items: 10 methods, 1 properties
#   • apacheairflowjob.pool_management: 4 methods, 1 properties
#   • apacheairflowjob.workspace_settings: 2 methods, 1 properties
#   • copyjob.items: 10 methods, 1 properties
#   • core.capacities: 1 methods, 1 properties
#   • core.connections: 11 methods, 1 properties
#   • core.deployment_pipelines: 17 methods, 1 properties
#   • core.deploymentpipelines: 18 methods, 1 properties
#   • core.domains: 2 methods, 1 properties
#   • core.external_data_shares_provider: 5 methods, 1 properties
#   • core.external_data_shares_recipient: 2 methods, 1 properties
#   • core.folders: 6 methods, 1 properties
#   • core.gateways: 13 methods, 1 properties
#   • core.git: 13 methods, 1 properties
#   • core.items: 13 methods, 1 properties
#   • core.job_scheduler: 9 methods, 1 properties
#   • core.long_running_operations: 2 methods, 1 properties
#   • core.managed_private_endpoints: 4 methods, 1 properties
#   • core.one_lake_data_access_security: 5 methods, 1 properties
#   • core.one_lake_settings: 3 methods, 1 properties
#   • core.one_lake_shortcuts: 6 methods, 1 properties
#   • core.onelakesettings: 4 methods, 1 properties
#   • core.onelakeshortcuts: 8 methods, 1 properties
#   • core.tags: 3 methods, 1 properties
#   • core.workspaces: 26 methods, 1 properties
#   • cosmosdbdatabase.items: 10 methods, 1 properties
#   • dashboard.items: 1 methods, 1 properties
#   • dataflow.background_jobs: 4 methods, 1 properties
#   • dataflow.items: 11 methods, 1 properties
#   • dataflow.query_execution: 1 methods, 1 properties
#   • dataflow.queryexecution: 2 methods, 1 properties
#   • datamart.items: 1 methods, 1 properties
#   • datapipeline.items: 10 methods, 1 properties
#   • digitaltwinbuilder.items: 10 methods, 1 properties
#   • digitaltwinbuilderflow.items: 10 methods, 1 properties
#   • environment.items: 14 methods, 1 properties
#   • environment.published: 5 methods, 1 properties
#   • environment.staging: 13 methods, 1 properties
#   • eventhouse.items: 10 methods, 1 properties
#   • eventstream.items: 10 methods, 1 properties
#   • eventstream.topology: 11 methods, 1 properties
#   • graphmodel.background_jobs: 1 methods, 1 properties
#   • graphmodel.items: 12 methods, 1 properties
#   • graphqlapi.items: 10 methods, 1 properties
#   • graphqueryset.items: 10 methods, 1 properties
#   • kqldashboard.items: 10 methods, 1 properties
#   • kqldatabase.items: 10 methods, 1 properties
#   • kqlqueryset.items: 10 methods, 1 properties
#   • lakehouse.background_jobs: 5 methods, 1 properties
#   • lakehouse.items: 10 methods, 1 properties
#   • lakehouse.livy_sessions: 3 methods, 1 properties
#   • lakehouse.tables: 3 methods, 1 properties
#   • map.items: 10 methods, 1 properties
#   • mirroredazuredatabrickscatalog.discovery: 3 methods, 1 properties
#   • mirroredazuredatabrickscatalog.items: 10 methods, 1 properties
#   • mirroredazuredatabrickscatalog.refresh: 2 methods, 1 properties
#   • mirroreddatabase.items: 9 methods, 1 properties
#   • mirroreddatabase.mirroring: 4 methods, 1 properties
#   • mirroredwarehouse.items: 1 methods, 1 properties
#   • mlexperiment.items: 6 methods, 1 properties
#   • mlmodel.endpoint: 15 methods, 1 properties
#   • mlmodel.items: 6 methods, 1 properties
#   • mounteddatafactory.items: 10 methods, 1 properties
#   • notebook.items: 10 methods, 1 properties
#   • notebook.livy_sessions: 3 methods, 1 properties
#   • ontology.items: 10 methods, 1 properties
#   • operationsagent.items: 10 methods, 1 properties
#   • paginatedreport.items: 2 methods, 1 properties
#   • reflex.items: 10 methods, 1 properties
#   • report.items: 10 methods, 1 properties
#   • semanticmodel.items: 11 methods, 1 properties
#   • spark.custom_pools: 5 methods, 1 properties
#   • spark.livy_sessions: 2 methods, 1 properties
#   • spark.workspace_settings: 2 methods, 1 properties
#   • sparkjobdefinition.background_jobs: 1 methods, 1 properties
#   • sparkjobdefinition.items: 10 methods, 1 properties
#   • sparkjobdefinition.livy_sessions: 3 methods, 1 properties
#   • sqldatabase.items: 10 methods, 1 properties
#   • sqldatabase.mirroring: 2 methods, 1 properties
#   • sqlendpoint.items: 4 methods, 1 properties
#   • sqlendpoint.sql_audit_settings: 3 methods, 1 properties
#   • userdatafunction.items: 10 methods, 1 properties
#   • variablelibrary.items: 10 methods, 1 properties
#   • warehouse.items: 7 methods, 1 properties
#   • warehouse.restore_points: 6 methods, 1 properties
#   • warehouse.restorepoints: 8 methods, 1 properties
#   • warehouse.sql_audit_settings: 3 methods, 1 properties
#   • warehousesnapshot.items: 6 methods, 1 properties

# %% [markdown]
# ## Summary Statistics

# %%
# Create a detailed summary
print("Microsoft Fabric API - Complete Summary")
print("=" * 80)

print("\nTop-Level Modules in fabric_client:")
for module_name in sorted(api_documentation["top_level_modules"]):
    print(f"  • {module_name}")

print(f"\n\nFabricClient Direct Methods: {len(api_documentation['client_methods'])}")
if api_documentation["client_methods"]:
    for method in api_documentation["client_methods"]:
        print(f"  • {method['name']}{method['signature']}")

total_methods = sum(len(m["methods"]) for m in api_documentation["all_modules"].values())
total_properties = sum(len(m.get("properties", [])) for m in api_documentation["all_modules"].values())

print("\n\nTotal Statistics:")
print(f"  • Top-level modules: {len(api_documentation['top_level_modules'])}")
print(f"  • Sub-modules explored: {len(api_documentation['all_modules'])}")
print(f"  • Total methods: {total_methods + len(api_documentation['client_methods'])}")
print(f"  • Total properties: {total_properties}")

print("\n\nDetailed Module Breakdown:")
for module_path, module_info in sorted(api_documentation["all_modules"].items()):
    print(f"\n  {module_path.upper()}")
    print(f"  {'-' * len(module_path)}")
    print(f"  Path: {module_info['path']}")
    print(f"  Type: {module_info['type']}")
    print(f"  Methods: {len(module_info['methods'])}")

    if module_info["methods"]:
        print("  Available operations:")
        for method in sorted(module_info["methods"], key=lambda x: x["name"])[:10]:  # Show first 10
            print(f"    • {method['name']}{method['signature']}")
        if len(module_info["methods"]) > 10:
            print(f"    ... and {len(module_info['methods']) - 10} more")

    if module_info.get("properties"):
        print(f"  Properties: {', '.join(p['name'] for p in module_info['properties'][:5])}")
        if len(module_info["properties"]) > 5:
            print(f"    ... and {len(module_info['properties']) - 5} more")
# Out:
# Microsoft Fabric API - Complete Summary
# ================================================================================
#
# Top-Level Modules in fabric_client:
#   • admin
#   • anomalydetector
#   • apacheairflowjob
#   • copyjob
#   • core
#   • cosmosdbdatabase
#   • dashboard
#   • dataflow
#   • datamart
#   • datapipeline
#   • digitaltwinbuilder
#   • digitaltwinbuilderflow
#   • environment
#   • eventhouse
#   • eventstream
#   • graphmodel
#   • graphqlapi
#   • graphqueryset
#   • kqldashboard
#   • kqldatabase
#   • kqlqueryset
#   • lakehouse
#   • map
#   • mirroredazuredatabrickscatalog
#   • mirroreddatabase
#   • mirroredwarehouse
#   • mlexperiment
#   • mlmodel
#   • mounteddatafactory
#   • notebook
#   • ontology
#   • operationsagent
#   • paginatedreport
#   • reflex
#   • report
#   • semanticmodel
#   • spark
#   • sparkjobdefinition
#   • sqldatabase
#   • sqlendpoint
#   • userdatafunction
#   • variablelibrary
#   • warehouse
#   • warehousesnapshot
#
#
# FabricClient Direct Methods: 0
#
#
# Total Statistics:
#   • Top-level modules: 44
#   • Sub-modules explored: 100
#   • Total methods: 705
#   • Total properties: 100
#
#
# Detailed Module Breakdown:
#
#   ADMIN.DOMAINS
#   -------------
#   Path: fabric_client.admin.domains
#   Type: DomainsOperations
#   Methods: 21
#   Available operations:
#     • assign_domain_workspaces_by_capacities(domain_id: None, assign_domain_workspaces_by_capacities_request: None) -> None
#     • assign_domain_workspaces_by_ids(domain_id: str, assign_domain_workspaces_by_ids_request: microsoft_fabric_api.generated.admin.models._models.AssignDomainWorkspacesByIdsRequest | IO[bytes], **kwargs: Any) -> None
#     • assign_domain_workspaces_by_principals(domain_id: None, assign_domain_workspaces_by_principals_request: None) -> None
#     • begin_assign_domain_workspaces_by_capacities(domain_id: None, assign_domain_workspaces_by_capacities_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • begin_assign_domain_workspaces_by_principals(domain_id: None, assign_domain_workspaces_by_principals_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • create_domain(create_domain_request: microsoft_fabric_api.generated.admin.models._models.CreateDomainRequest | IO[bytes], *, preview: bool, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.Domain
#     • create_domain_preview(create_domain_request: microsoft_fabric_api.generated.admin.models._models.CreateDomainRequest | IO[bytes], *, preview: bool, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.DomainPreview
#     • delete_domain(domain_id: str, **kwargs: Any) -> None
#     • get_domain(domain_id: str, *, preview: bool, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.Domain
#     • get_domain_preview(domain_id: str, *, preview: bool, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.DomainPreview
#     ... and 11 more
#   Properties: models
#
#   ADMIN.EXTERNAL_DATA_SHARES_PROVIDER
#   -----------------------------------
#   Path: fabric_client.admin.external_data_shares_provider
#   Type: ExternalDataSharesProviderOperations
#   Methods: 2
#   Available operations:
#     • list_external_data_shares(*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ExternalDataShare')]
#     • revoke_external_data_share(workspace_id: str, item_id: str, external_data_share_id: str, **kwargs: Any) -> None
#   Properties: models
#
#   ADMIN.ITEMS
#   -----------
#   Path: fabric_client.admin.items
#   Type: ItemsOperations
#   Methods: 3
#   Available operations:
#     • get_item(workspace_id: str, item_id: str, *, type: str | None = None, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.Item
#     • list_item_access_details(workspace_id: str, item_id: str, *, type: str | None = None, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.ItemAccessDetailsResponse
#     • list_items(*, workspace_id: str | None = None, capacity_id: str | None = None, state: str | None = None, type: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Item')]
#   Properties: models
#
#   ADMIN.LABELS
#   ------------
#   Path: fabric_client.admin.labels
#   Type: LabelsOperations
#   Methods: 2
#   Available operations:
#     • bulk_remove_labels(remove_labels_request: microsoft_fabric_api.generated.admin.models._models.RemoveLabelsRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.ItemsChangeLabelResponse
#     • bulk_set_labels(set_labels_request: microsoft_fabric_api.generated.admin.models._models.SetLabelsRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.ItemsChangeLabelResponse
#   Properties: models
#
#   ADMIN.SHARING_LINKS
#   -------------------
#   Path: fabric_client.admin.sharing_links
#   Type: SharingLinksOperations
#   Methods: 2
#   Available operations:
#     • begin_bulk_remove_sharing_links(bulk_remove_sharing_links_request: microsoft_fabric_api.generated.admin.models._models.BulkRemoveSharingLinksRequest | IO[bytes], **kwargs: Any) -> azure.core.polling._poller.LROPoller[microsoft_fabric_api.generated.admin.models._models.BulkRemoveSharingLinksResponse]
#     • begin_remove_all_sharing_links(remove_all_sharing_links_request: microsoft_fabric_api.generated.admin.models._models.RemoveAllSharingLinksRequest | IO[bytes], **kwargs: Any) -> azure.core.polling._poller.LROPoller[NoneType]
#   Properties: models
#
#   ADMIN.SHARINGLINKS
#   ------------------
#   Path: fabric_client.admin.sharinglinks
#   Type: SharingLinksOperations
#   Methods: 4
#   Available operations:
#     • begin_bulk_remove_sharing_links(bulk_remove_sharing_links_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.admin.models._models.BulkRemoveSharingLinksResponse]
#     • begin_remove_all_sharing_links(remove_all_sharing_links_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • bulk_remove_sharing_links(bulk_remove_sharing_links_request: None) -> microsoft_fabric_api.generated.admin.models._models.BulkRemoveSharingLinksResponse
#     • remove_all_sharing_links(remove_all_sharing_links_request: None) -> None
#   Properties: models
#
#   ADMIN.TAGS
#   ----------
#   Path: fabric_client.admin.tags
#   Type: TagsOperations
#   Methods: 4
#   Available operations:
#     • bulk_create_tags(create_tags_request: microsoft_fabric_api.generated.admin.models._models.CreateTagsRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.CreateTagsResponse
#     • delete_tag(tag_id: str, **kwargs: Any) -> None
#     • list_tags(*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.AdminTagInfo')]
#     • update_tag(tag_id: str, update_tag_request: microsoft_fabric_api.generated.admin.models._models.UpdateTagRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.Tag
#   Properties: models
#
#   ADMIN.TENANTS
#   -------------
#   Path: fabric_client.admin.tenants
#   Type: TenantsOperations
#   Methods: 8
#   Available operations:
#     • delete_capacity_tenant_setting_override(capacity_id: str, tenant_setting_name: str, **kwargs: Any) -> None
#     • list_capacities_tenant_settings_overrides(*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.CapacityTenantSettingOverride')]
#     • list_capacity_tenant_settings_overrides_by_capacity_id(capacity_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.CapacityTenantSetting')]
#     • list_domains_tenant_settings_overrides(*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.DomainTenantSettingOverride')]
#     • list_tenant_settings(*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.TenantSetting')]
#     • list_workspaces_tenant_settings_overrides(*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.WorkspaceTenantSettingOverride')]
#     • update_capacity_tenant_setting_override(capacity_id: str, tenant_setting_name: str, update_tenant_setting_override_request: microsoft_fabric_api.generated.admin.models._models.UpdateCapacityTenantSettingOverrideRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.UpdateCapacityTenantSettingOverrideResponse
#     • update_tenant_setting(tenant_setting_name: str, update_tenant_setting_request: microsoft_fabric_api.generated.admin.models._models.UpdateTenantSettingRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.UpdateTenantSettingResponse
#   Properties: models
#
#   ADMIN.USERS
#   -----------
#   Path: fabric_client.admin.users
#   Type: UsersOperations
#   Methods: 1
#   Available operations:
#     • list_access_entities(user_id: str, *, type: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.AccessEntity')]
#   Properties: models
#
#   ADMIN.WORKSPACES
#   ----------------
#   Path: fabric_client.admin.workspaces
#   Type: WorkspacesOperations
#   Methods: 6
#   Available operations:
#     • get_workspace(workspace_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.Workspace
#     • list_git_connections(*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.GitConnectionDetails')]
#     • list_networking_communication_policies(*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.NetworkCommunicationPolicyDetails')]
#     • list_workspace_access_details(workspace_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.admin.models._models.WorkspaceAccessDetailsResponse
#     • list_workspaces(*, type: str | None = None, capacity_id: str | None = None, name: str | None = None, state: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Workspace')]
#     • restore_workspace(workspace_id: str, restore_workspace_request: microsoft_fabric_api.generated.admin.models._models.RestoreWorkspaceRequest | IO[bytes], **kwargs: Any) -> None
#   Properties: models
#
#   ANOMALYDETECTOR.ITEMS
#   ---------------------
#   Path: fabric_client.anomalydetector.items
#   Type: ItemsOperations
#   Methods: 10
#   Available operations:
#     • begin_create_anomaly_detector(workspace_id: None, create_anomaly_detector_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.anomalydetector.models._models.AnomalyDetector]
#     • begin_get_anomaly_detector_definition(workspace_id: None, anomaly_detector_id: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.anomalydetector.models._models.AnomalyDetectorDefinitionResponse]
#     • begin_update_anomaly_detector_definition(workspace_id: None, anomaly_detector_id: None, update_anomaly_detector_definition_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • create_anomaly_detector(workspace_id: None, create_anomaly_detector_request: None) -> microsoft_fabric_api.generated.anomalydetector.models._models.AnomalyDetector
#     • delete_anomaly_detector(workspace_id: str, anomaly_detector_id: str, **kwargs: Any) -> None
#     • get_anomaly_detector(workspace_id: str, anomaly_detector_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.anomalydetector.models._models.AnomalyDetector
#     • get_anomaly_detector_definition(workspace_id: None, anomaly_detector_id: None) -> microsoft_fabric_api.generated.anomalydetector.models._models.AnomalyDetectorDefinitionResponse
#     • list_anomaly_detectors(workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.AnomalyDetector')]
#     • update_anomaly_detector(workspace_id: str, anomaly_detector_id: str, update_anomaly_detector_request: microsoft_fabric_api.generated.anomalydetector.models._models.UpdateAnomalyDetectorRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.anomalydetector.models._models.AnomalyDetector
#     • update_anomaly_detector_definition(workspace_id: None, anomaly_detector_id: None, update_anomaly_detector_definition_request: None) -> None
#   Properties: models
#
#   APACHEAIRFLOWJOB.FILES
#   ----------------------
#   Path: fabric_client.apacheairflowjob.files
#   Type: FilesOperations
#   Methods: 4
#   Available operations:
#     • create_or_update_apache_airflow_job_file_beta(workspace_id: str, apache_airflow_job_id: str, file_path: str, file_contents: IO[bytes], *, beta: bool = True, **kwargs: Any) -> None
#     • delete_apache_airflow_job_file_beta(workspace_id: str, apache_airflow_job_id: str, file_path: str, *, beta: bool = True, **kwargs: Any) -> None
#     • get_apache_airflow_job_file_beta(workspace_id: str, apache_airflow_job_id: str, file_path: str, *, beta: bool = True, **kwargs: Any) -> Iterator[bytes]
#     • list_apache_airflow_job_files_beta(workspace_id: str, apache_airflow_job_id: str, *, root_path: str | None = None, beta: bool = True, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ApacheAirflowJobFileMetadata')]
#   Properties: models
#
#   APACHEAIRFLOWJOB.ITEMS
#   ----------------------
#   Path: fabric_client.apacheairflowjob.items
#   Type: ItemsOperations
#   Methods: 10
#   Available operations:
#     • begin_create_apache_airflow_job(workspace_id: None, create_apache_airflow_job_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.apacheairflowjob.models._models.ApacheAirflowJob]
#     • begin_get_apache_airflow_job_definition(workspace_id: None, apache_airflow_job_id: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.apacheairflowjob.models._models.ApacheAirflowJobDefinitionResponse]
#     • begin_update_apache_airflow_job_definition(workspace_id: None, apache_airflow_job_id: None, update_apache_airflow_job_definition_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • create_apache_airflow_job(workspace_id: None, create_apache_airflow_job_request: None) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.ApacheAirflowJob
#     • delete_apache_airflow_job(workspace_id: str, apache_airflow_job_id: str, **kwargs: Any) -> None
#     • get_apache_airflow_job(workspace_id: str, apache_airflow_job_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.ApacheAirflowJob
#     • get_apache_airflow_job_definition(workspace_id: None, apache_airflow_job_id: None) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.ApacheAirflowJobDefinitionResponse
#     • list_apache_airflow_jobs(workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ApacheAirflowJob')]
#     • update_apache_airflow_job(workspace_id: str, apache_airflow_job_id: str, update_apache_airflow_job_request: microsoft_fabric_api.generated.apacheairflowjob.models._models.UpdateApacheAirflowJobRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.ApacheAirflowJob
#     • update_apache_airflow_job_definition(workspace_id: None, apache_airflow_job_id: None, update_apache_airflow_job_definition_request: None) -> None
#   Properties: models
#
#   APACHEAIRFLOWJOB.POOL_MANAGEMENT
#   --------------------------------
#   Path: fabric_client.apacheairflowjob.pool_management
#   Type: PoolManagementOperations
#   Methods: 4
#   Available operations:
#     • create_airflow_pool_template_beta(workspace_id: str, create_airflow_pool_template_request: microsoft_fabric_api.generated.apacheairflowjob.models._models.CreateAirflowPoolTemplateRequest | IO[bytes], *, beta: bool = True, **kwargs: Any) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.AirflowPoolTemplate
#     • delete_airflow_pool_template_beta(workspace_id: str, pool_template_id: str, *, beta: bool = True, **kwargs: Any) -> None
#     • get_airflow_pool_template_beta(workspace_id: str, pool_template_id: str, *, beta: bool = True, **kwargs: Any) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.AirflowPoolTemplate
#     • list_airflow_pool_templates_beta(workspace_id: str, *, continuation_token_parameter: str | None = None, beta: bool = True, **kwargs: Any) -> Iterable[ForwardRef('_models.AirflowPoolTemplate')]
#   Properties: models
#
#   APACHEAIRFLOWJOB.WORKSPACE_SETTINGS
#   -----------------------------------
#   Path: fabric_client.apacheairflowjob.workspace_settings
#   Type: WorkspaceSettingsOperations
#   Methods: 2
#   Available operations:
#     • get_airflow_workspace_settings_beta(workspace_id: str, *, beta: bool = True, **kwargs: Any) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.AirflowWorkspaceSettings
#     • update_airflow_workspace_settings_beta(workspace_id: str, update_airflow_workspace_settings_request: microsoft_fabric_api.generated.apacheairflowjob.models._models.UpdateAirflowWorkspaceSettingsRequest | IO[bytes], *, beta: bool = True, **kwargs: Any) -> microsoft_fabric_api.generated.apacheairflowjob.models._models.AirflowWorkspaceSettings
#   Properties: models
#
#   COPYJOB.ITEMS
#   -------------
#   Path: fabric_client.copyjob.items
#   Type: ItemsOperations
#   Methods: 10
#   Available operations:
#     • begin_create_copy_job(workspace_id: None, create_copy_job_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.copyjob.models._models.CopyJob]
#     • begin_get_copy_job_definition(workspace_id: None, copy_job_id: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.copyjob.models._models.CopyJobDefinitionResponse]
#     • begin_update_copy_job_definition(workspace_id: None, copy_job_id: None, update_copy_job_definition_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • create_copy_job(workspace_id: None, create_copy_job_request: None) -> microsoft_fabric_api.generated.copyjob.models._models.CopyJob
#     • delete_copy_job(workspace_id: str, copy_job_id: str, **kwargs: Any) -> None
#     • get_copy_job(workspace_id: str, copy_job_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.copyjob.models._models.CopyJob
#     • get_copy_job_definition(workspace_id: None, copy_job_id: None) -> microsoft_fabric_api.generated.copyjob.models._models.CopyJobDefinitionResponse
#     • list_copy_jobs(workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.CopyJob')]
#     • update_copy_job(workspace_id: str, copy_job_id: str, update_copy_job_request: microsoft_fabric_api.generated.copyjob.models._models.UpdateCopyJobRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.copyjob.models._models.CopyJob
#     • update_copy_job_definition(workspace_id: None, copy_job_id: None, update_copy_job_definition_request: None) -> None
#   Properties: models
#
#   CORE.CAPACITIES
#   ---------------
#   Path: fabric_client.core.capacities
#   Type: CapacitiesOperations
#   Methods: 1
#   Available operations:
#     • list_capacities(*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Capacity')]
#   Properties: models
#
#   CORE.CONNECTIONS
#   ----------------
#   Path: fabric_client.core.connections
#   Type: ConnectionsOperations
#   Methods: 11
#   Available operations:
#     • add_connection_role_assignment(connection_id: str, add_connection_role_assignment_request: microsoft_fabric_api.generated.core.models._models.AddConnectionRoleAssignmentRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.ConnectionRoleAssignment
#     • create_connection(create_connection_request: microsoft_fabric_api.generated.core.models._models.CreateConnectionRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Connection
#     • delete_connection(connection_id: str, **kwargs: Any) -> None
#     • delete_connection_role_assignment(connection_id: str, connection_role_assignment_id: str, **kwargs: Any) -> None
#     • get_connection(connection_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Connection
#     • get_connection_role_assignment(connection_id: str, connection_role_assignment_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.ConnectionRoleAssignment
#     • list_connection_role_assignments(connection_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ConnectionRoleAssignment')]
#     • list_connections(*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Connection')]
#     • list_supported_connection_types(*, gateway_id: str | None = None, show_all_creation_methods: bool | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ConnectionCreationMetadata')]
#     • update_connection(connection_id: str, update_connection_request: microsoft_fabric_api.generated.core.models._models.UpdateConnectionRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Connection
#     ... and 1 more
#   Properties: models
#
#   CORE.DEPLOYMENT_PIPELINES
#   -------------------------
#   Path: fabric_client.core.deployment_pipelines
#   Type: DeploymentPipelinesOperations
#   Methods: 17
#   Available operations:
#     • add_deployment_pipeline_role_assignment(deployment_pipeline_id: str, deployment_pipeline_role_assignment_request: microsoft_fabric_api.generated.core.models._models.AddDeploymentPipelineRoleAssignmentRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.DeploymentPipelineRoleAssignment
#     • assign_workspace_to_stage(deployment_pipeline_id: str, stage_id: str, deployment_pipeline_assign_workspace_request: microsoft_fabric_api.generated.core.models._models.DeploymentPipelineAssignWorkspaceRequest | IO[bytes], **kwargs: Any) -> None
#     • begin_deploy_stage_content(deployment_pipeline_id: str, deploy_request: microsoft_fabric_api.generated.core.models._models.DeployRequest | IO[bytes], **kwargs: Any) -> azure.core.polling._poller.LROPoller[microsoft_fabric_api.generated.core.models._models.DeploymentPipelineOperationExtendedInfo]
#     • create_deployment_pipeline(create_deployment_pipeline_request: microsoft_fabric_api.generated.core.models._models.CreateDeploymentPipelineRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.DeploymentPipelineExtendedInfo
#     • delete_deployment_pipeline(deployment_pipeline_id: str, **kwargs: Any) -> None
#     • delete_deployment_pipeline_role_assignment(deployment_pipeline_id: str, principal_id: str, **kwargs: Any) -> None
#     • get_deployment_pipeline(deployment_pipeline_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.DeploymentPipelineExtendedInfo
#     • get_deployment_pipeline_operation(deployment_pipeline_id: str, operation_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.DeploymentPipelineOperationExtendedInfo
#     • get_deployment_pipeline_stage(deployment_pipeline_id: str, stage_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.DeploymentPipelineStage
#     • list_deployment_pipeline_operations(deployment_pipeline_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.DeploymentPipelineOperation')]
#     ... and 7 more
#   Properties: models
#
#   CORE.DEPLOYMENTPIPELINES
#   ------------------------
#   Path: fabric_client.core.deploymentpipelines
#   Type: DeploymentPipelinesOperations
#   Methods: 18
#   Available operations:
#     • add_deployment_pipeline_role_assignment(deployment_pipeline_id: str, deployment_pipeline_role_assignment_request: microsoft_fabric_api.generated.core.models._models.AddDeploymentPipelineRoleAssignmentRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.DeploymentPipelineRoleAssignment
#     • assign_workspace_to_stage(deployment_pipeline_id: str, stage_id: str, deployment_pipeline_assign_workspace_request: microsoft_fabric_api.generated.core.models._models.DeploymentPipelineAssignWorkspaceRequest | IO[bytes], **kwargs: Any) -> None
#     • begin_deploy_stage_content(deployment_pipeline_id: None, deploy_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.core.models._models.DeploymentPipelineOperationExtendedInfo]
#     • create_deployment_pipeline(create_deployment_pipeline_request: microsoft_fabric_api.generated.core.models._models.CreateDeploymentPipelineRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.DeploymentPipelineExtendedInfo
#     • delete_deployment_pipeline(deployment_pipeline_id: str, **kwargs: Any) -> None
#     • delete_deployment_pipeline_role_assignment(deployment_pipeline_id: str, principal_id: str, **kwargs: Any) -> None
#     • deploy_stage_content(deployment_pipeline_id: None, deploy_request: None) -> microsoft_fabric_api.generated.core.models._models.DeploymentPipelineOperationExtendedInfo
#     • get_deployment_pipeline(deployment_pipeline_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.DeploymentPipelineExtendedInfo
#     • get_deployment_pipeline_operation(deployment_pipeline_id: str, operation_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.DeploymentPipelineOperationExtendedInfo
#     • get_deployment_pipeline_stage(deployment_pipeline_id: str, stage_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.DeploymentPipelineStage
#     ... and 8 more
#   Properties: models
#
#   CORE.DOMAINS
#   ------------
#   Path: fabric_client.core.domains
#   Type: DomainsOperations
#   Methods: 2
#   Available operations:
#     • get_domain(domain_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Domain
#     • list_domains(*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Domain')]
#   Properties: models
#
#   CORE.EXTERNAL_DATA_SHARES_PROVIDER
#   ----------------------------------
#   Path: fabric_client.core.external_data_shares_provider
#   Type: ExternalDataSharesProviderOperations
#   Methods: 5
#   Available operations:
#     • create_external_data_share(workspace_id: str, item_id: str, create_external_data_share_request: microsoft_fabric_api.generated.core.models._models.CreateExternalDataShareRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.ExternalDataShare
#     • delete_external_data_share(workspace_id: str, item_id: str, external_data_share_id: str, **kwargs: Any) -> None
#     • get_external_data_share(workspace_id: str, item_id: str, external_data_share_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.ExternalDataShare
#     • list_external_data_shares_in_item(workspace_id: str, item_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ExternalDataShare')]
#     • revoke_external_data_share(workspace_id: str, item_id: str, external_data_share_id: str, **kwargs: Any) -> None
#   Properties: models
#
#   CORE.EXTERNAL_DATA_SHARES_RECIPIENT
#   -----------------------------------
#   Path: fabric_client.core.external_data_shares_recipient
#   Type: ExternalDataSharesRecipientOperations
#   Methods: 2
#   Available operations:
#     • accept_external_data_share_invitation(invitation_id: str, accept_external_data_share_request: microsoft_fabric_api.generated.core.models._models.AcceptExternalDataShareInvitationRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.AcceptExternalDataShareInvitationResponse
#     • get_external_data_share_invitation_details(invitation_id: str, *, provider_tenant_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.ExternalDataShareInvitationDetails
#   Properties: models
#
#   CORE.FOLDERS
#   ------------
#   Path: fabric_client.core.folders
#   Type: FoldersOperations
#   Methods: 6
#   Available operations:
#     • create_folder(workspace_id: str, create_folder_request: microsoft_fabric_api.generated.core.models._models.CreateFolderRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Folder
#     • delete_folder(workspace_id: str, folder_id: str, **kwargs: Any) -> None
#     • get_folder(workspace_id: str, folder_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Folder
#     • list_folders(workspace_id: str, *, root_folder_id: str | None = None, recursive: bool | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Folder')]
#     • move_folder(workspace_id: str, folder_id: str, move_folder_request: microsoft_fabric_api.generated.core.models._models.MoveFolderRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Folder
#     • update_folder(workspace_id: str, folder_id: str, update_folder_request: microsoft_fabric_api.generated.core.models._models.UpdateFolderRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Folder
#   Properties: models
#
#   CORE.GATEWAYS
#   -------------
#   Path: fabric_client.core.gateways
#   Type: GatewaysOperations
#   Methods: 13
#   Available operations:
#     • add_gateway_role_assignment(gateway_id: str, add_gateway_role_assignment_request: microsoft_fabric_api.generated.core.models._models.AddGatewayRoleAssignmentRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.GatewayRoleAssignment
#     • create_gateway(create_gateway_request: microsoft_fabric_api.generated.core.models._models.CreateGatewayRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Gateway
#     • delete_gateway(gateway_id: str, **kwargs: Any) -> None
#     • delete_gateway_member(gateway_id: str, gateway_member_id: str, **kwargs: Any) -> None
#     • delete_gateway_role_assignment(gateway_id: str, gateway_role_assignment_id: str, **kwargs: Any) -> None
#     • get_gateway(gateway_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Gateway
#     • get_gateway_role_assignment(gateway_id: str, gateway_role_assignment_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.GatewayRoleAssignment
#     • list_gateway_members(gateway_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.ListGatewayMembersResponse
#     • list_gateway_role_assignments(gateway_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.GatewayRoleAssignment')]
#     • list_gateways(*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Gateway')]
#     ... and 3 more
#   Properties: models
#
#   CORE.GIT
#   --------
#   Path: fabric_client.core.git
#   Type: GitOperations
#   Methods: 13
#   Available operations:
#     • begin_commit_to_git(workspace_id: None, commit_to_git_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • begin_get_status(workspace_id: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.core.models._models.GitStatusResponse]
#     • begin_initialize_connection(workspace_id: None, git_initialize_connection_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.core.models._models.InitializeGitConnectionResponse]
#     • begin_update_from_git(workspace_id: None, update_from_git_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • commit_to_git(workspace_id: None, commit_to_git_request: None) -> None
#     • connect(workspace_id: str, git_connect_request: microsoft_fabric_api.generated.core.models._models.GitConnectRequest | IO[bytes], **kwargs: Any) -> None
#     • disconnect(workspace_id: str, **kwargs: Any) -> None
#     • get_connection(workspace_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.GitConnection
#     • get_my_git_credentials(workspace_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.GitCredentialsConfigurationResponse
#     • get_status(workspace_id: None) -> microsoft_fabric_api.generated.core.models._models.GitStatusResponse
#     ... and 3 more
#   Properties: models
#
#   CORE.ITEMS
#   ----------
#   Path: fabric_client.core.items
#   Type: ItemsOperations
#   Methods: 13
#   Available operations:
#     • begin_create_item(workspace_id: None, create_item_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.core.models._models.Item]
#     • begin_get_item_definition(workspace_id: None, item_id: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.core.models._models.ItemDefinitionResponse]
#     • begin_update_item_definition(workspace_id: None, item_id: None, update_item_definition_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • bulk_move_items(workspace_id: str, bulk_move_items_request: microsoft_fabric_api.generated.core.models._models.BulkMoveItemsRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.MovedItems
#     • create_item(workspace_id: None, create_item_request: None) -> microsoft_fabric_api.generated.core.models._models.Item
#     • delete_item(workspace_id: str, item_id: str, **kwargs: Any) -> None
#     • get_item(workspace_id: str, item_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Item
#     • get_item_definition(workspace_id: None, item_id: None) -> microsoft_fabric_api.generated.core.models._models.ItemDefinitionResponse
#     • list_item_connections(workspace_id: str, item_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ItemConnection')]
#     • list_items(workspace_id: str, *, type: str | None = None, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Item')]
#     ... and 3 more
#   Properties: models
#
#   CORE.JOB_SCHEDULER
#   ------------------
#   Path: fabric_client.core.job_scheduler
#   Type: JobSchedulerOperations
#   Methods: 9
#   Available operations:
#     • cancel_item_job_instance(workspace_id: str, item_id: str, job_instance_id: str, **kwargs: Any) -> None
#     • create_item_schedule(workspace_id: str, item_id: str, job_type: str, create_schedule_request: microsoft_fabric_api.generated.core.models._models.CreateScheduleRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.ItemSchedule
#     • delete_item_schedule(workspace_id: str, item_id: str, job_type: str, schedule_id: str, **kwargs: Any) -> None
#     • get_item_job_instance(workspace_id: str, item_id: str, job_instance_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.ItemJobInstance
#     • get_item_schedule(workspace_id: str, item_id: str, job_type: str, schedule_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.ItemSchedule
#     • list_item_job_instances(workspace_id: str, item_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ItemJobInstance')]
#     • list_item_schedules(workspace_id: str, item_id: str, job_type: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ItemSchedule')]
#     • run_on_demand_item_job(workspace_id: str, item_id: str, job_type: str, run_on_demand_item_job_request: microsoft_fabric_api.generated.core.models._models.RunOnDemandItemJobRequest | IO[bytes] | None = None, **kwargs: Any) -> None
#     • update_item_schedule(workspace_id: str, item_id: str, job_type: str, schedule_id: str, update_schedule_request: microsoft_fabric_api.generated.core.models._models.UpdateScheduleRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.ItemSchedule
#   Properties: models
#
#   CORE.LONG_RUNNING_OPERATIONS
#   ----------------------------
#   Path: fabric_client.core.long_running_operations
#   Type: LongRunningOperationsOperations
#   Methods: 2
#   Available operations:
#     • get_operation_result(operation_id: str, **kwargs: Any) -> Iterator[bytes]
#     • get_operation_state(operation_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.OperationState
#   Properties: models
#
#   CORE.MANAGED_PRIVATE_ENDPOINTS
#   ------------------------------
#   Path: fabric_client.core.managed_private_endpoints
#   Type: ManagedPrivateEndpointsOperations
#   Methods: 4
#   Available operations:
#     • create_workspace_managed_private_endpoint(workspace_id: str, create_managed_private_endpoint_request: microsoft_fabric_api.generated.core.models._models.CreateManagedPrivateEndpointRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.ManagedPrivateEndpoint
#     • delete_workspace_managed_private_endpoint(workspace_id: str, managed_private_endpoint_id: str, **kwargs: Any) -> None
#     • get_workspace_managed_private_endpoint(workspace_id: str, managed_private_endpoint_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.ManagedPrivateEndpoint
#     • list_workspace_managed_private_endpoints(workspace_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ManagedPrivateEndpoint')]
#   Properties: models
#
#   CORE.ONE_LAKE_DATA_ACCESS_SECURITY
#   ----------------------------------
#   Path: fabric_client.core.one_lake_data_access_security
#   Type: OneLakeDataAccessSecurityOperations
#   Methods: 5
#   Available operations:
#     • create_or_update_data_access_roles(workspace_id: str, item_id: str, create_or_update_data_access_roles_request: microsoft_fabric_api.generated.core.models._models.CreateOrUpdateDataAccessRolesRequest | IO[bytes], *, dry_run: bool | None = None, etag: str | None = None, match_condition: azure.core._match_conditions.MatchConditions | None = None, **kwargs: Any) -> None
#     • create_or_update_single_data_access_role(workspace_id: str, item_id: str, create_or_update_single_data_access_role_request: microsoft_fabric_api.generated.core.models._models.CreateOrUpdateSingleDataAccessRoleRequest | IO[bytes], *, data_access_role_conflict_policy: str | microsoft_fabric_api.generated.core.models._enums.DataAccessRoleConflictPolicy | None = None, etag: str | None = None, match_condition: azure.core._match_conditions.MatchConditions | None = None, **kwargs: Any) -> None
#     • delete_data_access_role(workspace_id: str, item_id: str, role_name: str, **kwargs: Any) -> None
#     • get_data_access_role(workspace_id: str, item_id: str, role_name: str, *, etag: str | None = None, match_condition: azure.core._match_conditions.MatchConditions | None = None, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.DataAccessRoleBase
#     • list_data_access_roles(workspace_id: str, item_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.DataAccessRoles
#   Properties: models
#
#   CORE.ONE_LAKE_SETTINGS
#   ----------------------
#   Path: fabric_client.core.one_lake_settings
#   Type: OneLakeSettingsOperations
#   Methods: 3
#   Available operations:
#     • begin_modify_diagnostics(workspace_id: str, modify_one_lake_diagnostic_setting_request: microsoft_fabric_api.generated.core.models._models.OneLakeDiagnosticSettings | IO[bytes] | None = None, **kwargs: Any) -> azure.core.polling._poller.LROPoller[NoneType]
#     • get_settings(workspace_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.GetOneLakeSettingsResponse
#     • modify_immutability_policy(workspace_id: str, immutability_policy_request: microsoft_fabric_api.generated.core.models._models.ImmutabilityPolicyRequest | IO[bytes], **kwargs: Any) -> None
#   Properties: models
#
#   CORE.ONE_LAKE_SHORTCUTS
#   -----------------------
#   Path: fabric_client.core.one_lake_shortcuts
#   Type: OneLakeShortcutsOperations
#   Methods: 6
#   Available operations:
#     • begin_creates_shortcuts_in_bulk(workspace_id: str, item_id: str, bulk_create_shortcuts_request: microsoft_fabric_api.generated.core.models._models.BulkCreateShortcutsRequest | IO[bytes], *, shortcut_conflict_policy: str | microsoft_fabric_api.generated.core.models._enums.ShortcutConflictPolicy | None = None, **kwargs: Any) -> azure.core.polling._poller.LROPoller[microsoft_fabric_api.generated.core.models._models.BulkCreateShortcutResponse]
#     • begin_reset_shortcut_cache(workspace_id: str, **kwargs: Any) -> azure.core.polling._poller.LROPoller[NoneType]
#     • create_shortcut(workspace_id: str, item_id: str, create_shortcut_request: microsoft_fabric_api.generated.core.models._models.CreateShortcutRequest | IO[bytes], *, shortcut_conflict_policy: str | microsoft_fabric_api.generated.core.models._enums.ShortcutConflictPolicy | None = None, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Shortcut
#     • delete_shortcut(workspace_id: str, item_id: str, shortcut_path: str, shortcut_name: str, **kwargs: Any) -> None
#     • get_shortcut(workspace_id: str, item_id: str, shortcut_path: str, shortcut_name: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Shortcut
#     • list_shortcuts(workspace_id: str, item_id: str, *, parent_path: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ShortcutTransformFlagged')]
#   Properties: models
#
#   CORE.ONELAKESETTINGS
#   --------------------
#   Path: fabric_client.core.onelakesettings
#   Type: OneLakeSettingsOperations
#   Methods: 4
#   Available operations:
#     • begin_modify_diagnostics(workspace_id: None, modify_one_lake_diagnostic_setting_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • get_settings(workspace_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.GetOneLakeSettingsResponse
#     • modify_diagnostics(workspace_id: None, modify_one_lake_diagnostic_setting_request: None) -> None
#     • modify_immutability_policy(workspace_id: str, immutability_policy_request: microsoft_fabric_api.generated.core.models._models.ImmutabilityPolicyRequest | IO[bytes], **kwargs: Any) -> None
#   Properties: models
#
#   CORE.ONELAKESHORTCUTS
#   ---------------------
#   Path: fabric_client.core.onelakeshortcuts
#   Type: OneLakeShortcutsOperations
#   Methods: 8
#   Available operations:
#     • begin_creates_shortcuts_in_bulk(workspace_id: None, item_id: None, bulk_create_shortcuts_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.core.models._models.BulkCreateShortcutResponse]
#     • begin_reset_shortcut_cache(workspace_id: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • create_shortcut(workspace_id: str, item_id: str, create_shortcut_request: microsoft_fabric_api.generated.core.models._models.CreateShortcutRequest | IO[bytes], *, shortcut_conflict_policy: str | microsoft_fabric_api.generated.core.models._enums.ShortcutConflictPolicy | None = None, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Shortcut
#     • creates_shortcuts_in_bulk(workspace_id: None, item_id: None, bulk_create_shortcuts_request: None) -> microsoft_fabric_api.generated.core.models._models.BulkCreateShortcutResponse
#     • delete_shortcut(workspace_id: str, item_id: str, shortcut_path: str, shortcut_name: str, **kwargs: Any) -> None
#     • get_shortcut(workspace_id: str, item_id: str, shortcut_path: str, shortcut_name: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Shortcut
#     • list_shortcuts(workspace_id: str, item_id: str, *, parent_path: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.ShortcutTransformFlagged')]
#     • reset_shortcut_cache(workspace_id: None) -> None
#   Properties: models
#
#   CORE.TAGS
#   ---------
#   Path: fabric_client.core.tags
#   Type: TagsOperations
#   Methods: 3
#   Available operations:
#     • apply_tags(workspace_id: str, item_id: str, apply_tags_request: microsoft_fabric_api.generated.core.models._models.ApplyTagsRequest | IO[bytes], **kwargs: Any) -> None
#     • list_tags(*, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Tag')]
#     • unapply_tags(workspace_id: str, item_id: str, unapply_tags_request: microsoft_fabric_api.generated.core.models._models.UnapplyTagsRequest | IO[bytes], **kwargs: Any) -> None
#   Properties: models
#
#   CORE.WORKSPACES
#   ---------------
#   Path: fabric_client.core.workspaces
#   Type: WorkspacesOperations
#   Methods: 26
#   Available operations:
#     • add_workspace_role_assignment(workspace_id: str, workspace_role_assignment_request: microsoft_fabric_api.generated.core.models._models.AddWorkspaceRoleAssignmentRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.WorkspaceRoleAssignment
#     • assign_to_capacity(workspace_id: str, assign_workspace_to_capacity_request: microsoft_fabric_api.generated.core.models._models.AssignWorkspaceToCapacityRequest | IO[bytes], **kwargs: Any) -> None
#     • assign_to_domain(workspace_id: str, assign_workspace_to_domain_request: microsoft_fabric_api.generated.core.models._models.AssignWorkspaceToDomainRequest | IO[bytes], **kwargs: Any) -> None
#     • begin_deprovision_identity(workspace_id: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • begin_provision_identity(workspace_id: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.core.models._models.WorkspaceIdentity]
#     • create_workspace(create_workspace_request: microsoft_fabric_api.generated.core.models._models.CreateWorkspaceRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.Workspace
#     • delete_workspace(workspace_id: str, **kwargs: Any) -> None
#     • delete_workspace_role_assignment(workspace_id: str, workspace_role_assignment_id: str, **kwargs: Any) -> None
#     • deprovision_identity(workspace_id: None) -> None
#     • get_git_outbound_policy(workspace_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.core.models._models.NetworkRules
#     ... and 16 more
#   Properties: models
#
#   COSMOSDBDATABASE.ITEMS
#   ----------------------
#   Path: fabric_client.cosmosdbdatabase.items
#   Type: ItemsOperations
#   Methods: 10
#   Available operations:
#     • begin_create_cosmos_db_database(workspace_id: None, create_cosmos_db_database_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.cosmosdbdatabase.models._models.CosmosDBDatabase]
#     • begin_get_cosmos_db_database_definition(workspace_id: None, cosmos_db_database_id: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.cosmosdbdatabase.models._models.CosmosDBDatabaseDefinitionResponse]
#     • begin_update_cosmos_db_database_definition(workspace_id: None, cosmos_db_database_id: None, update_cosmos_db_database_definition_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • create_cosmos_db_database(workspace_id: None, create_cosmos_db_database_request: None) -> microsoft_fabric_api.generated.cosmosdbdatabase.models._models.CosmosDBDatabase
#     • delete_cosmos_db_database(workspace_id: str, cosmos_db_database_id: str, **kwargs: Any) -> None
#     • get_cosmos_db_database(workspace_id: str, cosmos_db_database_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.cosmosdbdatabase.models._models.CosmosDBDatabase
# ...
#     • list_livy_sessions_beta(workspace_id: str, spark_job_definition_id: str, *, beta: bool, submitted_date_time: datetime.datetime | None = None, end_date_time: datetime.datetime | None = None, submitter_id: str | None = None, state: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.LivySession')]
#   Properties: models
#
#   SQLDATABASE.ITEMS
#   -----------------
#   Path: fabric_client.sqldatabase.items
#   Type: ItemsOperations
#   Methods: 10
#   Available operations:
#     • begin_create_sql_database(workspace_id: None, create_sql_database_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.sqldatabase.models._models.SQLDatabase]
#     • begin_get_sql_database_definition(workspace_id: None, sql_database_id: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.sqldatabase.models._models.SQLDatabaseDefinitionResponse]
#     • begin_update_sql_databases_definition(workspace_id: None, sql_database_id: None, update_sql_database_definition_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • create_sql_database(workspace_id: None, create_sql_database_request: None) -> microsoft_fabric_api.generated.sqldatabase.models._models.SQLDatabase
#     • delete_sql_database(workspace_id: str, sql_database_id: str, **kwargs: Any) -> None
#     • get_sql_database(workspace_id: str, sql_database_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.sqldatabase.models._models.SQLDatabase
#     • get_sql_database_definition(workspace_id: None, sql_database_id: None) -> microsoft_fabric_api.generated.sqldatabase.models._models.SQLDatabaseDefinitionResponse
#     • list_sql_databases(workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.SQLDatabase')]
#     • update_sql_database(workspace_id: str, sql_database_id: str, update_sql_database_request: microsoft_fabric_api.generated.sqldatabase.models._models.UpdateSQLDatabaseRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.sqldatabase.models._models.SQLDatabase
#     • update_sql_databases_definition(workspace_id: None, sql_database_id: None, update_sql_database_definition_request: None) -> None
#   Properties: models
#
#   SQLDATABASE.MIRRORING
#   ---------------------
#   Path: fabric_client.sqldatabase.mirroring
#   Type: MirroringOperations
#   Methods: 2
#   Available operations:
#     • start_mirroring(workspace_id: str, sql_database_id: str, **kwargs: Any) -> None
#     • stop_mirroring(workspace_id: str, sql_database_id: str, **kwargs: Any) -> None
#   Properties: models
#
#   SQLENDPOINT.ITEMS
#   -----------------
#   Path: fabric_client.sqlendpoint.items
#   Type: ItemsOperations
#   Methods: 4
#   Available operations:
#     • begin_refresh_sql_endpoint_metadata(workspace_id: None, sql_endpoint_id: None, sql_endpoint_refresh_metadata_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.sqlendpoint.models._models.TableSyncStatuses]
#     • get_connection_string(workspace_id: str, sql_endpoint_id: str, *, guest_tenant_id: str | None = None, private_link_type: str | microsoft_fabric_api.generated.sqlendpoint.models._enums.PrivateLinkType | None = None, **kwargs: Any) -> microsoft_fabric_api.generated.sqlendpoint.models._models.ConnectionStringResponse
#     • list_sql_endpoints(workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.SQLEndpoint')]
#     • refresh_sql_endpoint_metadata(workspace_id: None, sql_endpoint_id: None, sql_endpoint_refresh_metadata_request: None) -> microsoft_fabric_api.generated.sqlendpoint.models._models.TableSyncStatuses
#   Properties: models
#
#   SQLENDPOINT.SQL_AUDIT_SETTINGS
#   ------------------------------
#   Path: fabric_client.sqlendpoint.sql_audit_settings
#   Type: SQLAuditSettingsOperations
#   Methods: 3
#   Available operations:
#     • get_sql_audit_settings(workspace_id: str, item_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.sqlendpoint.models._models.SqlAuditSettings
#     • set_audit_actions_and_groups(workspace_id: str, item_id: str, set_audit_actions_and_groups_request: List[str] | IO[bytes], **kwargs: Any) -> None
#     • update_sql_audit_settings(workspace_id: str, item_id: str, update_audit_settings_request: microsoft_fabric_api.generated.sqlendpoint.models._models.SqlAuditSettingsUpdate | IO[bytes] | None = None, **kwargs: Any) -> microsoft_fabric_api.generated.sqlendpoint.models._models.SqlAuditSettings
#   Properties: models
#
#   USERDATAFUNCTION.ITEMS
#   ----------------------
#   Path: fabric_client.userdatafunction.items
#   Type: ItemsOperations
#   Methods: 10
#   Available operations:
#     • begin_create_user_data_function(workspace_id: None, create_user_data_function_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.userdatafunction.models._models.UserDataFunction]
#     • begin_get_user_data_function_definition(workspace_id: None, user_data_function_id: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.userdatafunction.models._models.UserDataFunctionDefinitionResponse]
#     • begin_update_user_data_function_definition(workspace_id: None, user_data_function_id: None, update_user_data_function_definition_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • create_user_data_function(workspace_id: None, create_user_data_function_request: None) -> microsoft_fabric_api.generated.userdatafunction.models._models.UserDataFunction
#     • delete_user_data_function(workspace_id: str, user_data_function_id: str, **kwargs: Any) -> None
#     • get_user_data_function(workspace_id: str, user_data_function_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.userdatafunction.models._models.UserDataFunction
#     • get_user_data_function_definition(workspace_id: None, user_data_function_id: None) -> microsoft_fabric_api.generated.userdatafunction.models._models.UserDataFunctionDefinitionResponse
#     • list_user_data_functions(workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.UserDataFunction')]
#     • update_user_data_function(workspace_id: str, user_data_function_id: str, update_user_data_function_request: microsoft_fabric_api.generated.userdatafunction.models._models.UpdateUserDataFunctionRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.userdatafunction.models._models.UserDataFunction
#     • update_user_data_function_definition(workspace_id: None, user_data_function_id: None, update_user_data_function_definition_request: None) -> None
#   Properties: models
#
#   VARIABLELIBRARY.ITEMS
#   ---------------------
#   Path: fabric_client.variablelibrary.items
#   Type: ItemsOperations
#   Methods: 10
#   Available operations:
#     • begin_create_variable_library(workspace_id: None, create_variable_library_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.variablelibrary.models._models.VariableLibrary]
#     • begin_get_variable_library_definition(workspace_id: None, variable_library_id: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.variablelibrary.models._models.VariableLibraryDefinitionResponse]
#     • begin_update_variable_library_definition(workspace_id: None, variable_library_id: None, update_variable_library_definition_request: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • create_variable_library(workspace_id: None, create_variable_library_request: None) -> microsoft_fabric_api.generated.variablelibrary.models._models.VariableLibrary
#     • delete_variable_library(workspace_id: str, variable_library_id: str, **kwargs: Any) -> None
#     • get_variable_library(workspace_id: str, variable_library_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.variablelibrary.models._models.VariableLibrary
#     • get_variable_library_definition(workspace_id: None, variable_library_id: None) -> microsoft_fabric_api.generated.variablelibrary.models._models.VariableLibraryDefinitionResponse
#     • list_variable_libraries(workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.VariableLibrary')]
#     • update_variable_library(workspace_id: str, variable_library_id: str, update_variable_library_request: microsoft_fabric_api.generated.variablelibrary.models._models.UpdateVariableLibraryRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.variablelibrary.models._models.VariableLibrary
#     • update_variable_library_definition(workspace_id: None, variable_library_id: None, update_variable_library_definition_request: None) -> None
#   Properties: models
#
#   WAREHOUSE.ITEMS
#   ---------------
#   Path: fabric_client.warehouse.items
#   Type: ItemsOperations
#   Methods: 7
#   Available operations:
#     • begin_create_warehouse(workspace_id: None, create_warehouse_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.warehouse.models._models.Warehouse]
#     • create_warehouse(workspace_id: None, create_warehouse_request: None) -> microsoft_fabric_api.generated.warehouse.models._models.Warehouse
#     • delete_warehouse(workspace_id: str, warehouse_id: str, **kwargs: Any) -> None
#     • get_connection_string(workspace_id: str, warehouse_id: str, *, guest_tenant_id: str | None = None, private_link_type: str | microsoft_fabric_api.generated.warehouse.models._enums.PrivateLinkType | None = None, **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.ConnectionStringResponse
#     • get_warehouse(workspace_id: str, warehouse_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.Warehouse
#     • list_warehouses(workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.Warehouse')]
#     • update_warehouse(workspace_id: str, warehouse_id: str, update_warehouse_request: microsoft_fabric_api.generated.warehouse.models._models.UpdateWarehouseRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.Warehouse
#   Properties: models
#
#   WAREHOUSE.RESTORE_POINTS
#   ------------------------
#   Path: fabric_client.warehouse.restore_points
#   Type: RestorePointsOperations
#   Methods: 6
#   Available operations:
#     • begin_create_restore_point(workspace_id: str, warehouse_id: str, create_restore_point_request: microsoft_fabric_api.generated.warehouse.models._models.CreateRestorePointRequest | IO[bytes], **kwargs: Any) -> azure.core.polling._poller.LROPoller[microsoft_fabric_api.generated.warehouse.models._models.RestorePoint]
#     • begin_restore_to_restore_point(workspace_id: str, warehouse_id: str, restore_point_id: str, **kwargs: Any) -> azure.core.polling._poller.LROPoller[NoneType]
#     • delete_restore_point(workspace_id: str, warehouse_id: str, restore_point_id: str, **kwargs: Any) -> None
#     • get_restore_point(workspace_id: str, warehouse_id: str, restore_point_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.RestorePoint
#     • list_restore_points(workspace_id: str, warehouse_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.RestorePoint')]
#     • update_restore_point(workspace_id: str, warehouse_id: str, restore_point_id: str, update_restore_point_request: microsoft_fabric_api.generated.warehouse.models._models.UpdateRestorePointRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.RestorePoint
#   Properties: models
#
#   WAREHOUSE.RESTOREPOINTS
#   -----------------------
#   Path: fabric_client.warehouse.restorepoints
#   Type: RestorePointsOperations
#   Methods: 8
#   Available operations:
#     • begin_create_restore_point(workspace_id: None, warehouse_id: None, create_restore_point_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.warehouse.models._models.RestorePoint]
#     • begin_restore_to_restore_point(workspace_id: None, warehouse_id: None, restore_point_id: None) -> azure.core.polling._poller.LROPoller[NoneType]
#     • create_restore_point(workspace_id: None, warehouse_id: None, create_restore_point_request: None) -> microsoft_fabric_api.generated.warehouse.models._models.RestorePoint
#     • delete_restore_point(workspace_id: str, warehouse_id: str, restore_point_id: str, **kwargs: Any) -> None
#     • get_restore_point(workspace_id: str, warehouse_id: str, restore_point_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.RestorePoint
#     • list_restore_points(workspace_id: str, warehouse_id: str, *, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.RestorePoint')]
#     • restore_to_restore_point(workspace_id: None, warehouse_id: None, restore_point_id: None) -> None
#     • update_restore_point(workspace_id: str, warehouse_id: str, restore_point_id: str, update_restore_point_request: microsoft_fabric_api.generated.warehouse.models._models.UpdateRestorePointRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.RestorePoint
#   Properties: models
#
#   WAREHOUSE.SQL_AUDIT_SETTINGS
#   ----------------------------
#   Path: fabric_client.warehouse.sql_audit_settings
#   Type: SQLAuditSettingsOperations
#   Methods: 3
#   Available operations:
#     • get_sql_audit_settings(workspace_id: str, item_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.SqlAuditSettings
#     • set_audit_actions_and_groups(workspace_id: str, item_id: str, set_audit_actions_and_groups_request: List[str] | IO[bytes], **kwargs: Any) -> None
#     • update_sql_audit_settings(workspace_id: str, item_id: str, update_audit_settings_request: microsoft_fabric_api.generated.warehouse.models._models.SqlAuditSettingsUpdate | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.warehouse.models._models.SqlAuditSettings
#   Properties: models
#
#   WAREHOUSESNAPSHOT.ITEMS
#   -----------------------
#   Path: fabric_client.warehousesnapshot.items
#   Type: ItemsOperations
#   Methods: 6
#   Available operations:
#     • begin_create_warehouse_snapshot(workspace_id: None, create_warehouse_snapshot_request: None) -> microsoft_fabric_api.fabric_api_utils._LROResultExtractor[microsoft_fabric_api.generated.warehousesnapshot.models._models.WarehouseSnapshot]
#     • create_warehouse_snapshot(workspace_id: None, create_warehouse_snapshot_request: None) -> microsoft_fabric_api.generated.warehousesnapshot.models._models.WarehouseSnapshot
#     • delete_warehouse_snapshot(workspace_id: str, warehouse_snapshot_id: str, **kwargs: Any) -> None
#     • get_warehouse_snapshot(workspace_id: str, warehouse_snapshot_id: str, **kwargs: Any) -> microsoft_fabric_api.generated.warehousesnapshot.models._models.WarehouseSnapshot
#     • list_warehouse_snapshots(workspace_id: str, *, recursive: bool | None = None, root_folder_id: str | None = None, continuation_token_parameter: str | None = None, **kwargs: Any) -> Iterable[ForwardRef('_models.WarehouseSnapshot')]
#     • update_warehouse_snapshot(workspace_id: str, warehouse_snapshot_id: str, update_warehouse_snapshot_request: microsoft_fabric_api.generated.warehousesnapshot.models._models.UpdateWarehouseSnapshotRequest | IO[bytes], **kwargs: Any) -> microsoft_fabric_api.generated.warehousesnapshot.models._models.WarehouseSnapshot
#   Properties: models
